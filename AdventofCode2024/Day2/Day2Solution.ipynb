# %%
def get_data(file):
    data=[]


    #open the file and strip out trailing whitespace

    with open(file, 'r') as f:
        for line in f:
            level = list(map(int, line.strip().split()))
            data.append(level)

    return data

# %% [markdown]
# <article class="day-desc"><h2>--- Day 2: Red-Nosed Reports ---</h2><p>Fortunately, the first location The Historians want to search isn't a long walk from the Chief Historian's office.</p>
# <p>While the <a href="/2015/day/19">Red-Nosed Reindeer nuclear fusion/fission plant</a> appears to contain no sign of the Chief Historian, the engineers there run up to you as soon as they see you. Apparently, they <em>still</em> talk about the time Rudolph was saved through molecular synthesis from a single electron.</p>
# <p>They're quick to add that - since you're already here - they'd really appreciate your help analyzing some unusual data from the Red-Nosed reactor. You turn to check if The Historians are waiting for you, but they seem to have already divided into groups that are currently searching every corner of the facility. You offer to help with the unusual data.</p>
# <p>The unusual data (your puzzle input) consists of many <em>reports</em>, one report per line. Each report is a list of numbers called <em>levels</em> that are separated by spaces. For example:</p>
# <pre><code>7 6 4 2 1
# 1 2 7 8 9
# 9 7 6 2 1
# 1 3 2 4 5
# 8 6 4 4 1
# 1 3 6 7 9
# </code></pre>
# <p>This example data contains six reports each containing five levels.</p>
# <p>The engineers are trying to figure out which reports are <em>safe</em>. The Red-Nosed reactor safety systems can only tolerate levels that are either gradually increasing or gradually decreasing. So, a report only counts as safe if both of the following are true:</p>
# <ul>
# <li>The levels are either <em>all increasing</em> or <em>all decreasing</em>.</li>
# <li>Any two adjacent levels differ by <em>at least one</em> and <em>at most three</em>.</li>
# </ul>
# <p>In the example above, the reports can be found safe or unsafe by checking those rules:</p>
# <ul>
# <li><code>7 6 4 2 1</code>: <em>Safe</em> because the levels are all decreasing by 1 or 2.</li>
# <li><code>1 2 7 8 9</code>: <em>Unsafe</em> because <code>2 7</code> is an increase of 5.</li>
# <li><code>9 7 6 2 1</code>: <em>Unsafe</em> because <code>6 2</code> is a decrease of 4.</li>
# <li><code>1 3 2 4 5</code>: <em>Unsafe</em> because <code>1 3</code> is increasing but <code>3 2</code> is decreasing.</li>
# <li><code>8 6 4 4 1</code>: <em>Unsafe</em> because <code>4 4</code> is neither an increase or a decrease.</li>
# <li><code>1 3 6 7 9</code>: <em>Safe</em> because the levels are all increasing by 1, 2, or 3.</li>
# </ul>
# <p>So, in this example, <code><em>2</em></code> reports are <em>safe</em>.</p>
# <p>Analyze the unusual data from the engineers. <em>How many reports are safe?</em></p>
# </article>

# %%
def part_one(data):

    safe = {}
    level_number = 1

    for level in data:

        diffs = []
        i = 1

        while i < len(level):
            diffs.append(level[i]-level[i-1])
            i+=1

        safe[level_number] = 0

        difference = all(1 <= abs(diff) <= 3 for diff in diffs)
        inc_dec = all(diff < 0 for diff in diffs) or all(diff > 0 for diff in diffs)


        if difference and inc_dec == True:
                safe[level_number] = 1

        level_number += 1

    return sum(safe.values())

print(part_one(get_data('Day2Input.txt')))
# Out:
# [48, 50, 51, 53, 55, 56, 59, 58] [2, 1, 2, 2, 1, 3, -1]
# True
# False
# False
#
# 0
# [12, 13, 14, 16, 17, 17] [1, 1, 2, 1, 0]
# False
# False
# False
#
# 0
# [10, 12, 14, 17, 20, 23, 26, 30] [2, 2, 3, 3, 3, 3, 4]
# False
# True
# False
#
# 0
# [13, 14, 16, 18, 19, 25] [1, 2, 2, 1, 6]
# False
# True
# False
#
# 0
# [2, 3, 4, 5, 8, 7, 9] [1, 1, 1, 3, -1, 2]
# True
# False
# False
#
# 0
# [19, 22, 21, 23, 21] [3, -1, 2, -2]
# True
# False
# False
#
# 0
# [49, 51, 53, 51, 53, 56, 56] [2, 2, -2, 2, 3, 0]
# False
# False
# False
#
# 0
# [16, 19, 22, 21, 25] [3, 3, -1, 4]
# False
# False
# False
#
# 0
# [20, 22, 25, 28, 25, 28, 34] [2, 3, 3, -3, 3, 6]
# False
# False
# False
#
# 0
# [38, 41, 43, 43, 44, 47, 50, 51] [3, 2, 0, 1, 3, 3, 1]
# False
# False
# False
#
# 0
# [19, 22, 25, 26, 26, 29, 32, 29] [3, 3, 1, 0, 3, 3, -3]
# False
# False
# False
#
# 0
# [31, 32, 32, 35, 35] [1, 0, 3, 0]
# False
# False
# False
#
# 0
# [43, 45, 46, 46, 50] [2, 1, 0, 4]
# False
# False
# False
#
# 0
# [70, 71, 72, 72, 78] [1, 1, 0, 6]
# False
# False
# False
#
# 0
# [43, 45, 49, 52, 55, 57, 59, 60] [2, 4, 3, 3, 2, 2, 1]
# False
# True
# False
#
# 0
# [19, 21, 23, 27, 26] [2, 2, 4, -1]
# False
# False
# False
#
# 0
# [87, 88, 92, 94, 95, 98, 98] [1, 4, 2, 1, 3, 0]
# False
# False
# False
#
# 0
# [12, 15, 17, 19, 21, 25, 27, 31] [3, 2, 2, 2, 4, 2, 4]
# False
# True
# False
#
# 0
# [58, 59, 60, 61, 63, 67, 70, 76] [1, 1, 1, 2, 4, 3, 6]
# False
# True
# False
#
# 0
# [54, 57, 60, 63, 65, 66, 71, 73] [3, 3, 3, 2, 1, 5, 2]
# False
# True
# False
#
# 0
# [78, 80, 82, 83, 84, 85, 90, 87] [2, 2, 1, 1, 1, 5, -3]
# False
# False
# False
#
# 0
# [83, 84, 91, 93, 94, 97, 97] [1, 7, 2, 1, 3, 0]
# False
# False
# False
#
# 0
# [55, 57, 64, 65, 68, 71, 73, 77] [2, 7, 1, 3, 3, 2, 4]
# False
# True
# False
#
# 0
# [59, 62, 65, 66, 71, 78] [3, 3, 1, 5, 7]
# False
# True
# False
#
# 0
# [69, 67, 70, 72, 73, 74, 76] [-2, 3, 2, 1, 1, 2]
# True
# False
# False
#
# 0
# [45, 44, 47, 50, 52, 51] [-1, 3, 3, 2, -1]
# True
# False
# False
#
# 0
# [42, 41, 43, 44, 47, 48, 48] [-1, 2, 1, 3, 1, 0]
# False
# False
# False
#
# 0
# [70, 69, 70, 71, 74, 75, 77, 81] [-1, 1, 1, 3, 1, 2, 4]
# False
# False
# False
#
# 0
# [60, 59, 60, 61, 62, 65, 66, 71] [-1, 1, 1, 1, 3, 1, 5]
# False
# False
# False
#
# 0
# [29, 28, 27, 29, 32] [-1, -1, 2, 3]
# True
# False
# False
#
# 0
# [55, 52, 55, 58, 61, 60, 63, 61] [-3, 3, 3, 3, -1, 3, -2]
# True
# False
# False
#
# 0
# [57, 55, 52, 53, 55, 56, 56] [-2, -3, 1, 2, 1, 0]
# False
# False
# False
#
# 0
# [21, 18, 20, 18, 19, 22, 26] [-3, 2, -2, 1, 3, 4]
# False
# False
# False
#
# 0
# [35, 34, 37, 35, 37, 44] [-1, 3, -2, 2, 7]
# False
# False
# False
#
# 0
# [61, 59, 59, 60, 62, 65, 68] [-2, 0, 1, 2, 3, 3]
# False
# False
# False
#
# 0
# [43, 41, 44, 44, 46, 47, 50, 49] [-2, 3, 0, 2, 1, 3, -1]
# False
# False
# False
#
# 0
# [27, 26, 29, 31, 31, 33, 33] [-1, 3, 2, 0, 2, 0]
# False
# False
# False
#
# 0
# [39, 36, 39, 39, 43] [-3, 3, 0, 4]
# False
# False
# False
#
# 0
# [10, 9, 10, 10, 13, 18] [-1, 1, 0, 3, 5]
# False
# False
# False
#
# 0
# [41, 40, 43, 45, 47, 51, 52] [-1, 3, 2, 2, 4, 1]
# False
# False
# False
#
# 0
# [16, 14, 18, 20, 21, 19] [-2, 4, 2, 1, -2]
# False
# False
# False
#
# 0
# [44, 42, 43, 44, 45, 49, 49] [-2, 1, 1, 1, 4, 0]
# False
# False
# False
#
# 0
# [10, 9, 11, 15, 16, 19, 23] [-1, 2, 4, 1, 3, 4]
# False
# False
# False
#
# 0
# [53, 51, 54, 57, 61, 66] [-2, 3, 3, 4, 5]
# False
# False
# False
#
# 0
# [3, 1, 2, 4, 10, 13] [-2, 1, 2, 6, 3]
# False
# False
# False
#
# 0
# [52, 50, 52, 58, 56] [-2, 2, 6, -2]
# False
# False
# False
#
# 0
# [25, 23, 26, 29, 31, 32, 39, 39] [-2, 3, 3, 2, 1, 7, 0]
# False
# False
# False
#
# 0
# [9, 7, 9, 14, 17, 20, 24] [-2, 2, 5, 3, 3, 4]
# False
# False
# False
#
# 0
# [10, 9, 10, 13, 14, 16, 22, 28] [-1, 1, 3, 1, 2, 6, 6]
# False
# False
# False
#
# 0
# [64, 64, 65, 66, 67] [0, 1, 1, 1]
# False
# False
# False
#
# 0
# [1, 1, 2, 3, 5, 6, 8, 6] [0, 1, 1, 2, 1, 2, -2]
# False
# False
# False
#
# 0
# [53, 53, 56, 57, 60, 61, 61] [0, 3, 1, 3, 1, 0]
# False
# False
# False
#
# 0
# [35, 35, 36, 37, 40, 42, 44, 48] [0, 1, 1, 3, 2, 2, 4]
# False
# False
# False
#
# 0
# [28, 28, 31, 32, 35, 41] [0, 3, 1, 3, 6]
# False
# False
# False
#
# 0
# [34, 34, 35, 38, 36, 39] [0, 1, 3, -2, 3]
# False
# False
# False
#
# 0
# [71, 71, 72, 71, 69] [0, 1, -1, -2]
# False
# False
# False
#
# 0
# [52, 52, 54, 51, 52, 55, 58, 58] [0, 2, -3, 1, 3, 3, 0]
# False
# False
# False
#
# 0
# [39, 39, 42, 43, 42, 44, 46, 50] [0, 3, 1, -1, 2, 2, 4]
# False
# False
# False
#
# 0
# [87, 87, 88, 86, 88, 91, 97] [0, 1, -2, 2, 3, 6]
# False
# False
# False
#
# 0
# [63, 63, 64, 64, 66, 67, 70, 73] [0, 1, 0, 2, 1, 3, 3]
# False
# False
# False
#
# 0
# [41, 41, 44, 45, 45, 42] [0, 3, 1, 0, -3]
# False
# False
# False
#
# 0
# [11, 11, 11, 14, 16, 16] [0, 0, 3, 2, 0]
# False
# False
# False
#
# 0
# [78, 78, 81, 84, 84, 86, 90] [0, 3, 3, 0, 2, 4]
# False
# False
# False
#
# 0
# [30, 30, 30, 31, 34, 36, 43] [0, 0, 1, 3, 2, 7]
# False
# False
# False
#
# 0
# [61, 61, 64, 66, 67, 71, 73, 75] [0, 3, 2, 1, 4, 2, 2]
# False
# False
# False
#
# 0
# [17, 17, 21, 22, 23, 20] [0, 4, 1, 1, -3]
# False
# False
# False
#
# 0
# [84, 84, 88, 89, 89] [0, 4, 1, 0]
# False
# False
# False
#
# 0
# [15, 15, 19, 21, 24, 28] [0, 4, 2, 3, 4]
# False
# False
# False
#
# 0
# [11, 11, 14, 18, 19, 26] [0, 3, 4, 1, 7]
# False
# False
# False
#
# 0
# [47, 47, 53, 54, 57, 59, 60, 62] [0, 6, 1, 3, 2, 1, 2]
# False
# False
# False
#
# 0
# [93, 93, 94, 99, 98] [0, 1, 5, -1]
# False
# False
# False
#
# 0
# [61, 61, 64, 65, 70, 71, 74, 74] [0, 3, 1, 5, 1, 3, 0]
# False
# False
# False
#
# 0
# [64, 64, 67, 68, 75, 78, 79, 83] [0, 3, 1, 7, 3, 1, 4]
# False
# False
# False
#
# 0
# [59, 59, 62, 69, 76] [0, 3, 7, 7]
# False
# False
# False
#
# 0
# [83, 87, 89, 92, 93, 95, 97] [4, 2, 3, 1, 2, 2]
# False
# True
# False
#
# 0
# [72, 76, 79, 82, 81] [4, 3, 3, -1]
# False
# False
# False
#
# 0
# [65, 69, 72, 74, 76, 76] [4, 3, 2, 2, 0]
# False
# False
# False
#
# 0
# [20, 24, 27, 28, 30, 33, 37] [4, 3, 1, 2, 3, 4]
# False
# True
# False
#
# 0
# [2, 6, 9, 12, 13, 19] [4, 3, 3, 1, 6]
# False
# True
# False
#
# 0
# [27, 31, 28, 31, 32] [4, -3, 3, 1]
# False
# False
# False
#
# 0
# [31, 35, 36, 38, 39, 37, 36] [4, 1, 2, 1, -2, -1]
# False
# False
# False
#
# 0
# [23, 27, 28, 30, 29, 32, 32] [4, 1, 2, -1, 3, 0]
# False
# False
# False
#
# 0
# [19, 23, 25, 23, 26, 29, 30, 34] [4, 2, -2, 3, 3, 1, 4]
# False
# False
# False
#
# 0
# [43, 47, 44, 47, 50, 56] [4, -3, 3, 3, 6]
# False
# False
# False
#
# 0
# [9, 13, 15, 17, 17, 19, 21] [4, 2, 2, 0, 2, 2]
# False
# False
# False
#
# 0
# [37, 41, 43, 43, 41] [4, 2, 0, -2]
# False
# False
# False
#
# 0
# [79, 83, 85, 87, 87, 87] [4, 2, 2, 0, 0]
# False
# False
# False
#
# 0
# [17, 21, 21, 23, 27] [4, 0, 2, 4]
# False
# False
# False
#
# 0
# [20, 24, 27, 28, 30, 30, 33, 40] [4, 3, 1, 2, 0, 3, 7]
# False
# False
# False
#
# 0
# [38, 42, 46, 48, 51] [4, 4, 2, 3]
# False
# True
# False
#
# 0
# [41, 45, 47, 51, 54, 53] [4, 2, 4, 3, -1]
# False
# False
# False
#
# 0
# [48, 52, 54, 56, 60, 63, 63] [4, 2, 2, 4, 3, 0]
# False
# False
# False
#
# 0
# [21, 25, 29, 30, 34] [4, 4, 1, 4]
# False
# True
# False
#
# 0
# [73, 77, 78, 82, 83, 86, 93] [4, 1, 4, 1, 3, 7]
# False
# True
# False
#
# 0
# [71, 75, 81, 84, 85] [4, 6, 3, 1]
# False
# True
# False
#
# 0
# [79, 83, 89, 90, 92, 91] [4, 6, 1, 2, -1]
# False
# False
# False
#
# 0
# [25, 29, 34, 37, 37] [4, 5, 3, 0]
# False
# False
# False
#
# 0
# [4, 8, 15, 18, 19, 23] [4, 7, 3, 1, 4]
# False
# True
# False
#
# 0
# [15, 19, 22, 29, 30, 31, 38] [4, 3, 7, 1, 1, 7]
# False
# True
# False
#
# 0
# [69, 76, 77, 80, 83] [7, 1, 3, 3]
# False
# True
# False
#
# 0
# [5, 10, 13, 15, 18, 15] [5, 3, 2, 3, -3]
# False
# False
# False
#
# 0
# [31, 36, 37, 38, 38] [5, 1, 1, 0]
# False
# False
# False
#
# 0
# [38, 45, 48, 49, 50, 51, 54, 58] [7, 3, 1, 1, 1, 3, 4]
# False
# True
# False
#
# 0
# [15, 20, 23, 26, 28, 31, 38] [5, 3, 3, 2, 3, 7]
# False
# True
# False
#
# 0
# [11, 16, 14, 17, 19, 21] [5, -2, 3, 2, 2]
# False
# False
# False
#
# 0
# [66, 73, 75, 77, 75, 76, 75] [7, 2, 2, -2, 1, -1]
# False
# False
# False
#
# 0
# [72, 77, 74, 76, 76] [5, -3, 2, 0]
# False
# False
# False
#
# 0
# [14, 21, 23, 24, 23, 26, 30] [7, 2, 1, -1, 3, 4]
# False
# False
# False
#
# 0
# [53, 58, 60, 63, 60, 62, 68] [5, 2, 3, -3, 2, 6]
# False
# False
# False
#
# 0
# [59, 65, 68, 71, 71, 73, 76] [6, 3, 3, 0, 2, 3]
# False
# False
# False
#
# 0
# [20, 25, 27, 29, 29, 31, 29] [5, 2, 2, 0, 2, -2]
# False
# False
# False
#
# 0
# [83, 89, 92, 95, 95, 97, 99, 99] [6, 3, 3, 0, 2, 2, 0]
# False
# False
# False
#
# 0
# [50, 56, 58, 61, 61, 63, 67] [6, 2, 3, 0, 2, 4]
# False
# False
# False
#
# 0
# [48, 54, 54, 57, 58, 60, 65] [6, 0, 3, 1, 2, 5]
# False
# False
# False
#
# 0
# [75, 80, 84, 86, 89, 90, 93] [5, 4, 2, 3, 1, 3]
# False
# True
# False
#
# 0
# [19, 26, 28, 29, 33, 32] [7, 2, 1, 4, -1]
# False
# False
# False
#
# 0
# [6, 11, 12, 16, 19, 19] [5, 1, 4, 3, 0]
# False
# False
# False
#
# 0
# [74, 80, 83, 84, 85, 89, 91, 95] [6, 3, 1, 1, 4, 2, 4]
# False
# True
# False
#
# 0
# [3, 10, 12, 16, 21] [7, 2, 4, 5]
# False
# True
# False
#
# 0
# [63, 70, 71, 76, 77, 80] [7, 1, 5, 1, 3]
# False
# True
# False
#
# 0
# [55, 62, 69, 72, 73, 70] [7, 7, 3, 1, -3]
# False
# False
# False
#
# 0
# [16, 21, 22, 24, 27, 29, 36, 36] [5, 1, 2, 3, 2, 7, 0]
# False
# False
# False
#
# 0
# [38, 44, 51, 54, 58] [6, 7, 3, 4]
# False
# True
# False
#
# 0
# [9, 14, 19, 20, 23, 24, 30] [5, 5, 1, 3, 1, 6]
# False
# True
# False
#
# 0
# [39, 37, 35, 32, 34] [-2, -2, -3, 2]
# True
# False
# False
#
# 0
# [52, 50, 47, 46, 44, 41, 39, 39] [-2, -3, -1, -2, -3, -2, 0]
# False
# False
# False
#
# 0
# [35, 34, 33, 31, 30, 27, 24, 20] [-1, -1, -2, -1, -3, -3, -4]
# False
# True
# False
#
# 0
# [75, 73, 70, 67, 62] [-2, -3, -3, -5]
# False
# True
# False
#
# 0
# [20, 19, 18, 16, 14, 17, 14] [-1, -1, -2, -2, 3, -3]
# True
# False
# False
#
# 0
# [44, 42, 43, 42, 40, 39, 40] [-2, 1, -1, -2, -1, 1]
# True
# False
# False
#
# 0
# [59, 57, 56, 54, 55, 52, 50, 50] [-2, -1, -2, 1, -3, -2, 0]
# False
# False
# False
#
# 0
# [63, 60, 59, 62, 59, 57, 53] [-3, -1, 3, -3, -2, -4]
# False
# False
# False
#
# 0
# [23, 21, 23, 22, 16] [-2, 2, -1, -6]
# False
# False
# False
#
# 0
# [69, 66, 63, 63, 60] [-3, -3, 0, -3]
# False
# False
# False
#
# 0
# [66, 64, 61, 59, 59, 58, 61] [-2, -3, -2, 0, -1, 3]
# False
# False
# False
#
# 0
# [45, 43, 43, 40, 40] [-2, 0, -3, 0]
# False
# False
# False
#
# 0
# [46, 44, 43, 43, 39] [-2, -1, 0, -4]
# False
# False
# False
#
# 0
# [38, 37, 35, 32, 32, 27] [-1, -2, -3, 0, -5]
# False
# False
# False
#
# 0
# [90, 89, 87, 84, 80, 77, 76] [-1, -2, -3, -4, -3, -1]
# False
# True
# False
#
# 0
# [60, 58, 57, 54, 50, 48, 49] [-2, -1, -3, -4, -2, 1]
# False
# False
# False
#
# 0
# [88, 85, 83, 81, 80, 76, 76] [-3, -2, -2, -1, -4, 0]
# False
# False
# False
#
# 0
# [51, 49, 45, 44, 40] [-2, -4, -1, -4]
# False
# True
# False
#
# 0
# [80, 79, 77, 73, 67] [-1, -2, -4, -6]
# False
# True
# False
#
# 0
# [80, 79, 76, 70, 68, 65] [-1, -3, -6, -2, -3]
# False
# True
# False
#
# 0
# [50, 49, 47, 41, 43] [-1, -2, -6, 2]
# False
# False
# False
#
# 0
# [70, 67, 64, 63, 57, 57] [-3, -3, -1, -6, 0]
# False
# False
# False
#
# 0
# [32, 30, 24, 22, 20, 18, 14] [-2, -6, -2, -2, -2, -4]
# False
# True
# False
#
# 0
# [81, 79, 73, 71, 68, 65, 59] [-2, -6, -2, -3, -3, -6]
# False
# True
# False
#
# 0
# [86, 87, 86, 84, 81] [1, -1, -2, -3]
# True
# False
# False
#
# 0
# [89, 92, 90, 87, 88] [3, -2, -3, 1]
# True
# False
# False
#
# 0
# [67, 70, 67, 64, 61, 59, 58, 58] [3, -3, -3, -3, -2, -1, 0]
# False
# False
# False
#
# 0
# [59, 60, 58, 55, 53, 51, 49, 45] [1, -2, -3, -2, -2, -2, -4]
# False
# False
# False
#
# 0
# [51, 53, 51, 48, 45, 42, 41, 36] [2, -2, -3, -3, -3, -1, -5]
# False
# False
# False
#
# 0
# [50, 53, 52, 50, 47, 45, 47, 46] [3, -1, -2, -3, -2, 2, -1]
# True
# False
# False
#
# 0
# [59, 62, 61, 62, 64] [3, -1, 1, 2]
# True
# False
# False
#
# 0
# [63, 65, 63, 62, 60, 62, 62] [2, -2, -1, -2, 2, 0]
# False
# False
# False
#
# 0
# [96, 98, 99, 98, 96, 93, 89] [2, 1, -1, -2, -3, -4]
# False
# False
# False
#
# 0
# [63, 66, 63, 61, 64, 57] [3, -3, -2, 3, -7]
# False
# False
# False
#
# 0
# [30, 32, 31, 31, 30, 29] [2, -1, 0, -1, -1]
# False
# False
# False
#
# 0
# [17, 18, 15, 15, 14, 12, 13] [1, -3, 0, -1, -2, 1]
# False
# False
# False
#
# 0
# [1, 4, 3, 3, 3] [3, -1, 0, 0]
# False
# False
# False
#
# 0
# [13, 15, 15, 13, 10, 8, 4] [2, 0, -2, -3, -2, -4]
# False
# False
# False
#
# 0
# [62, 63, 60, 58, 58, 52] [1, -3, -2, 0, -6]
# False
# False
# False
#
# 0
# [80, 82, 81, 77, 76] [2, -1, -4, -1]
# False
# False
# False
#
# 0
# [85, 88, 87, 84, 81, 80, 76, 79] [3, -1, -3, -3, -1, -4, 3]
# False
# False
# False
#
# 0
# [86, 87, 85, 81, 78, 78] [1, -2, -4, -3, 0]
# False
# False
# False
#
# 0
# [94, 97, 96, 94, 93, 90, 86, 82] [3, -1, -2, -1, -3, -4, -4]
# False
# False
# False
#
# 0
# [58, 61, 57, 55, 54, 52, 46] [3, -4, -2, -1, -2, -6]
# False
# False
# False
#
# 0
# [17, 18, 15, 9, 7, 5, 3] [1, -3, -6, -2, -2, -2]
# False
# False
# False
#
# 0
# [25, 26, 24, 22, 16, 15, 12, 15] [1, -2, -2, -6, -1, -3, 3]
# False
# False
# False
#
# 0
# [57, 58, 52, 51, 48, 47, 47] [1, -6, -1, -3, -1, 0]
# False
# False
# False
#
# 0
# [62, 64, 59, 57, 53] [2, -5, -2, -4]
# False
# False
# False
#
# 0
# [41, 43, 36, 34, 32, 31, 26] [2, -7, -2, -2, -1, -5]
# False
# False
# False
#
# 0
# [16, 16, 13, 10, 7, 6, 3] [0, -3, -3, -3, -1, -3]
# False
# False
# False
#
# 0
# [39, 39, 38, 37, 34, 35] [0, -1, -1, -3, 1]
# False
# False
# False
#
# 0
# [32, 32, 30, 28, 27, 26, 25, 25] [0, -2, -2, -1, -1, -1, 0]
# False
# False
# False
#
# 0
# [56, 56, 53, 50, 47, 43] [0, -3, -3, -3, -4]
# False
# False
# False
#
# 0
# [60, 60, 58, 57, 54, 51, 45] [0, -2, -1, -3, -3, -6]
# False
# False
# False
#
# 0
# [29, 29, 30, 29, 26, 24] [0, 1, -1, -3, -2]
# False
# False
# False
#
# 0
# [79, 79, 78, 80, 81] [0, -1, 2, 1]
# False
# False
# False
#
# 0
# [56, 56, 53, 52, 53, 53] [0, -3, -1, 1, 0]
# False
# False
# False
#
# 0
# [48, 48, 45, 43, 46, 44, 40] [0, -3, -2, 3, -2, -4]
# False
# False
# False
#
# 0
# [80, 80, 79, 80, 75] [0, -1, 1, -5]
# False
# False
# False
#
# 0
# [34, 34, 34, 32, 31, 29, 26] [0, 0, -2, -1, -2, -3]
# False
# False
# False
#
# 0
# [11, 11, 11, 9, 7, 10] [0, 0, -2, -2, 3]
# False
# False
# False
#
# 0
# [62, 62, 60, 60, 60] [0, -2, 0, 0]
# False
# False
# False
#
# 0
# [84, 84, 81, 81, 78, 76, 75, 71] [0, -3, 0, -3, -2, -1, -4]
# False
# False
# False
#
# 0
# [54, 54, 54, 53, 51, 45] [0, 0, -1, -2, -6]
# False
# False
# False
#
# 0
# [60, 60, 59, 58, 56, 55, 51, 50] [0, -1, -1, -2, -1, -4, -1]
# False
# False
# False
#
# 0
# [85, 85, 84, 80, 81] [0, -1, -4, 1]
# False
# False
# False
#
# 0
# [95, 95, 93, 92, 88, 88] [0, -2, -1, -4, 0]
# False
# False
# False
#
# 0
# [65, 65, 61, 60, 58, 54] [0, -4, -1, -2, -4]
# False
# False
# False
#
# 0
# [95, 95, 91, 88, 81] [0, -4, -3, -7]
# False
# False
# False
#
# 0
# [79, 79, 72, 71, 70] [0, -7, -1, -1]
# False
# False
# False
#
# 0
# [46, 46, 39, 38, 41] [0, -7, -1, 3]
# False
# False
# False
#
# 0
# [40, 40, 33, 30, 30] [0, -7, -3, 0]
# False
# False
# False
#
# 0
# [40, 40, 34, 31, 28, 24] [0, -6, -3, -3, -4]
# False
# False
# False
#
# 0
# [61, 61, 56, 54, 51, 44] [0, -5, -2, -3, -7]
# False
# False
# False
#
# 0
# [43, 39, 36, 35, 33, 31] [-4, -3, -1, -2, -2]
# False
# True
# False
#
# 0
# [48, 44, 41, 40, 37, 35, 32, 35] [-4, -3, -1, -3, -2, -3, 3]
# False
# False
# False
#
# 0
# [53, 49, 46, 44, 41, 38, 38] [-4, -3, -2, -3, -3, 0]
# False
# False
# False
#
# 0
# [45, 41, 40, 38, 36, 34, 32, 28] [-4, -1, -2, -2, -2, -2, -4]
# False
# True
# False
#
# 0
# [42, 38, 36, 33, 30, 27, 24, 19] [-4, -2, -3, -3, -3, -3, -5]
# False
# True
# False
#
# 0
# [62, 58, 55, 56, 54, 53] [-4, -3, 1, -2, -1]
# False
# False
# False
#
# 0
# [5, 1, 2, 1, 2] [-4, 1, -1, 1]
# False
# False
# False
#
# 0
# [77, 73, 70, 73, 72, 70, 70] [-4, -3, 3, -1, -2, 0]
# False
# False
# False
#
# 0
# [33, 29, 26, 28, 24] [-4, -3, 2, -4]
# False
# False
# False
#
# 0
# [89, 85, 82, 85, 82, 76] [-4, -3, 3, -3, -6]
# False
# False
# False
#
# 0
# [84, 80, 79, 78, 78, 75] [-4, -1, -1, 0, -3]
# False
# False
# False
#
# 0
# [75, 71, 71, 70, 71] [-4, 0, -1, 1]
# False
# False
# False
#
# 0
# [76, 72, 69, 67, 67, 64, 64] [-4, -3, -2, 0, -3, 0]
# False
# False
# False
#
# 0
# [22, 18, 17, 15, 14, 11, 11, 7] [-4, -1, -2, -1, -3, 0, -4]
# False
# False
# False
#
# 0
# [31, 27, 27, 24, 19] [-4, 0, -3, -5]
# False
# False
# False
#
# 0
# [57, 53, 50, 47, 43, 41] [-4, -3, -3, -4, -2]
# False
# True
# False
#
# 0
# [97, 93, 90, 86, 83, 85] [-4, -3, -4, -3, 2]
# False
# False
# False
#
# 0
# [50, 46, 44, 43, 41, 37, 34, 34] [-4, -2, -1, -2, -4, -3, 0]
# False
# False
# False
#
# 0
# [18, 14, 10, 9, 6, 2] [-4, -4, -1, -3, -4]
# False
# True
# False
#
# 0
# [69, 65, 61, 60, 59, 57, 55, 49] [-4, -4, -1, -1, -2, -2, -6]
# False
# True
# False
#
# 0
# [73, 69, 67, 65, 58, 57] [-4, -2, -2, -7, -1]
# False
# True
# False
#
# 0
# [22, 18, 12, 11, 13] [-4, -6, -1, 2]
# False
# False
# False
#
# 0
# [25, 21, 20, 18, 17, 11, 10, 10] [-4, -1, -2, -1, -6, -1, 0]
# False
# False
# False
#
# 0
# [86, 82, 80, 74, 72, 69, 65] [-4, -2, -6, -2, -3, -4]
# False
# True
# False
#
# 0
# [97, 93, 90, 84, 77] [-4, -3, -6, -7]
# False
# True
# False
#
# 0
# [96, 91, 90, 88, 86, 85, 82] [-5, -1, -2, -2, -1, -3]
# False
# True
# False
#
# 0
# [88, 83, 82, 79, 78, 76, 78] [-5, -1, -3, -1, -2, 2]
# False
# False
# False
#
# 0
# [22, 15, 14, 13, 13] [-7, -1, -1, 0]
# False
# False
# False
#
# 0
# [70, 65, 62, 60, 57, 53] [-5, -3, -2, -3, -4]
# False
# True
# False
#
# 0
# [43, 36, 34, 33, 32, 25] [-7, -2, -1, -1, -7]
# False
# True
# False
#
# 0
# [12, 7, 6, 4, 2, 5, 3] [-5, -1, -2, -2, 3, -2]
# False
# False
# False
#
# 0
# [20, 13, 10, 8, 10, 9, 7, 8] [-7, -3, -2, 2, -1, -2, 1]
# False
# False
# False
#
# 0
# [85, 80, 79, 80, 77, 74, 74] [-5, -1, 1, -3, -3, 0]
# False
# False
# False
#
# 0
# [18, 13, 10, 11, 10, 9, 5] [-5, -3, 1, -1, -1, -4]
# False
# False
# False
#
# 0
# [49, 44, 45, 43, 41, 34] [-5, 1, -2, -2, -7]
# False
# False
# False
#
# 0
# [84, 79, 76, 76, 74] [-5, -3, 0, -2]
# False
# False
# False
#
# 0
# [60, 53, 51, 51, 48, 45, 44, 46] [-7, -2, 0, -3, -3, -1, 2]
# False
# False
# False
#
# 0
# [48, 42, 39, 38, 37, 35, 35, 35] [-6, -3, -1, -1, -2, 0, 0]
# False
# False
# False
#
# 0
# [62, 56, 56, 54, 53, 52, 48] [-6, 0, -2, -1, -1, -4]
# False
# False
# False
#
# 0
# [49, 42, 42, 40, 37, 31] [-7, 0, -2, -3, -6]
# False
# False
# False
#
# 0
# [94, 88, 86, 83, 82, 80, 76, 73] [-6, -2, -3, -1, -2, -4, -3]
# False
# True
# False
#
# 0
# [30, 25, 21, 20, 17, 18] [-5, -4, -1, -3, 1]
# False
# False
# False
#
# 0
# [65, 58, 57, 53, 52, 49, 49] [-7, -1, -4, -1, -3, 0]
# False
# False
# False
#
# 0
# [35, 29, 25, 22, 21, 18, 14] [-6, -4, -3, -1, -3, -4]
# False
# True
# False
#
# 0
# [37, 30, 28, 27, 23, 22, 21, 16] [-7, -2, -1, -4, -1, -1, -5]
# False
# True
# False
#
# 0
# [83, 77, 76, 70, 68] [-6, -1, -6, -2]
# False
# True
# False
#
# 0
# [61, 54, 53, 48, 46, 47] [-7, -1, -5, -2, 1]
# False
# False
# False
#
# 0
# [48, 42, 40, 34, 33, 31, 29, 29] [-6, -2, -6, -1, -2, -2, 0]
# False
# False
# False
#
# 0
# [87, 80, 77, 70, 66] [-7, -3, -7, -4]
# False
# True
# False
#
# 0
# [71, 66, 63, 57, 56, 55, 50] [-5, -3, -6, -1, -1, -5]
# False
# True
# False
#
# 0
# [80, 81, 84, 86, 89, 91, 88] [1, 3, 2, 3, 2, -3]
# True
# False
# False
#
# 0
# [23, 25, 26, 27, 30, 32, 35, 35] [2, 1, 1, 3, 2, 3, 0]
# False
# False
# False
#
# 0
# [82, 83, 85, 87, 88, 91, 95] [1, 2, 2, 1, 3, 4]
# False
# True
# False
#
# 0
# [42, 44, 47, 48, 49, 52, 54, 61] [2, 3, 1, 1, 3, 2, 7]
# False
# True
# False
#
# 0
# [90, 91, 93, 94, 91, 94, 96] [1, 2, 1, -3, 3, 2]
# True
# False
# False
#
# 0
# [15, 18, 15, 17, 20, 21, 23, 20] [3, -3, 2, 3, 1, 2, -3]
# True
# False
# False
#
# 0
# [86, 88, 89, 91, 88, 88] [2, 1, 2, -3, 0]
# False
# False
# False
#
# 0
# [1, 4, 5, 8, 5, 9] [3, 1, 3, -3, 4]
# False
# False
# False
#
# 0
# [57, 58, 59, 56, 58, 61, 63, 69] [1, 1, -3, 2, 3, 2, 6]
# False
# False
# False
#
# 0
# [77, 79, 79, 80, 81, 82, 83] [2, 0, 1, 1, 1, 1]
# False
# False
# False
#
# 0
# [87, 90, 90, 93, 95, 96, 95] [3, 0, 3, 2, 1, -1]
# False
# False
# False
#
# 0
# [77, 79, 80, 82, 84, 85, 85, 85] [2, 1, 2, 2, 1, 0, 0]
# False
# False
# False
#
# 0
# [43, 44, 46, 47, 48, 48, 49, 53] [1, 2, 1, 1, 0, 1, 4]
# False
# False
# False
#
# 0
# [50, 52, 55, 56, 57, 60, 60, 67] [2, 3, 1, 1, 3, 0, 7]
# False
# False
# False
#
# 0
# [29, 30, 32, 36, 39, 41, 44] [1, 2, 4, 3, 2, 3]
# False
# True
# False
#
# 0
# [70, 73, 76, 80, 81, 82, 79] [3, 3, 4, 1, 1, -3]
# False
# False
# False
#
# 0
# [5, 8, 10, 11, 15, 15] [3, 2, 1, 4, 0]
# False
# False
# False
#
# 0
# [5, 8, 10, 14, 16, 18, 22] [3, 2, 4, 2, 2, 4]
# False
# True
# False
#
# 0
# [36, 38, 40, 42, 45, 48, 52, 58] [2, 2, 2, 3, 3, 4, 6]
# False
# True
# False
#
# 0
# [84, 87, 89, 94, 97, 99] [3, 2, 5, 3, 2]
# False
# True
# False
#
# 0
# [29, 31, 34, 35, 41, 38] [2, 3, 1, 6, -3]
# False
# False
# False
#
# 0
# [43, 45, 47, 52, 55, 57, 57] [2, 2, 5, 3, 2, 0]
# False
# False
# False
#
# 0
# [68, 69, 71, 76, 80] [1, 2, 5, 4]
# False
# True
# False
#
# 0
# [79, 82, 83, 85, 92, 98] [3, 1, 2, 7, 6]
# False
# True
# False
#
# 0
# [31, 29, 31, 34, 35, 38, 41, 42] [-2, 2, 3, 1, 3, 3, 1]
# True
# False
# False
#
# 0
# [91, 88, 89, 92, 95, 96, 97, 94] [-3, 1, 3, 3, 1, 1, -3]
# True
# False
# False
#
# 0
# [28, 25, 28, 30, 31, 34, 37, 37] [-3, 3, 2, 1, 3, 3, 0]
# False
# False
# False
#
# 0
# [48, 45, 46, 49, 53] [-3, 1, 3, 4]
# False
# False
# False
#
# 0
# [18, 15, 17, 20, 27] [-3, 2, 3, 7]
# False
# False
# False
#
# 0
# [84, 83, 85, 83, 84] [-1, 2, -2, 1]
# True
# False
# False
#
# 0
# [9, 6, 8, 9, 8, 11, 10] [-3, 2, 1, -1, 3, -1]
# True
# False
# False
#
# 0
# [87, 85, 86, 89, 92, 91, 94, 94] [-2, 1, 3, 3, -1, 3, 0]
# False
# False
# False
#
# 0
# [10, 8, 7, 10, 13, 16, 20] [-2, -1, 3, 3, 3, 4]
# False
# False
# False
#
# 0
# [57, 56, 58, 55, 56, 57, 63] [-1, 2, -3, 1, 1, 6]
# False
# False
# False
#
# 0
# [91, 89, 91, 92, 94, 94, 95, 96] [-2, 2, 1, 2, 0, 1, 1]
# False
# False
# False
#
# 0
# [27, 26, 28, 28, 30, 31, 33, 32] [-1, 2, 0, 2, 1, 2, -1]
# False
# False
# False
#
# 0
# [88, 85, 88, 90, 90, 90] [-3, 3, 2, 0, 0]
# False
# False
# False
#
# 0
# [72, 70, 71, 71, 75] [-2, 1, 0, 4]
# False
# False
# False
#
# 0
# [19, 18, 18, 21, 27] [-1, 0, 3, 6]
# False
# False
# False
#
# 0
# [85, 84, 87, 91, 93, 96] [-1, 3, 4, 2, 3]
# False
# False
# False
#
# 0
# [76, 73, 74, 75, 78, 79, 83, 81] [-3, 1, 1, 3, 1, 4, -2]
# False
# False
# False
#
# 0
# [78, 76, 78, 82, 83, 85, 85] [-2, 2, 4, 1, 2, 0]
# False
# False
# False
#
# 0
# [6, 4, 8, 11, 14, 18] [-2, 4, 3, 3, 4]
# False
# False
# False
#
# 0
# [17, 14, 18, 19, 26] [-3, 4, 1, 7]
# False
# False
# False
#
# 0
# [54, 53, 58, 60, 62] [-1, 5, 2, 2]
# False
# False
# False
#
# 0
# [74, 73, 75, 80, 78] [-1, 2, 5, -2]
# False
# False
# False
#
# 0
# [19, 16, 23, 24, 24] [-3, 7, 1, 0]
# False
# False
# False
#
# 0
# [81, 79, 85, 88, 90, 91, 95] [-2, 6, 3, 2, 1, 4]
# False
# False
# False
#
# 0
# [24, 21, 24, 25, 28, 34, 37, 44] [-3, 3, 1, 3, 6, 3, 7]
# False
# False
# False
#
# 0
# [86, 86, 89, 92, 93] [0, 3, 3, 1]
# False
# False
# False
#
# 0
# [73, 73, 75, 77, 79, 81, 83, 82] [0, 2, 2, 2, 2, 2, -1]
# False
# False
# False
#
# 0
# [56, 56, 58, 61, 64, 65, 68, 68] [0, 2, 3, 3, 1, 3, 0]
# False
# False
# False
#
# 0
# [24, 24, 25, 27, 28, 29, 31, 35] [0, 1, 2, 1, 1, 2, 4]
# False
# False
# False
#
# 0
# [79, 79, 80, 82, 85, 91] [0, 1, 2, 3, 6]
# False
# False
# False
#
# 0
# [93, 93, 95, 92, 94, 95, 96] [0, 2, -3, 2, 1, 1]
# False
# False
# False
#
# 0
# [9, 9, 11, 10, 11, 9] [0, 2, -1, 1, -2]
# False
# False
# False
#
# 0
# [79, 79, 80, 77, 79, 79] [0, 1, -3, 2, 0]
# False
# False
# False
#
# 0
# [1, 1, 4, 7, 8, 10, 9, 13] [0, 3, 3, 1, 2, -1, 4]
# False
# False
# False
#
# 0
# [79, 79, 81, 83, 85, 84, 89] [0, 2, 2, 2, -1, 5]
# False
# False
# False
#
# 0
# [69, 69, 71, 73, 75, 76, 76, 79] [0, 2, 2, 2, 1, 0, 3]
# False
# False
# False
#
# 0
# [94, 94, 94, 95, 96, 99, 97] [0, 0, 1, 1, 3, -2]
# False
# False
# False
#
# 0
# [28, 28, 31, 31, 32, 33, 33] [0, 3, 0, 1, 1, 0]
# False
# False
# False
#
# 0
# [71, 71, 72, 73, 73, 77] [0, 1, 1, 0, 4]
# False
# False
# False
#
# 0
# [32, 32, 35, 36, 36, 41] [0, 3, 1, 0, 5]
# False
# False
# False
#
# 0
# [78, 78, 79, 83, 84, 87, 89, 90] [0, 1, 4, 1, 3, 2, 1]
# False
# False
# False
#
# 0
# [11, 11, 14, 18, 21, 23, 25, 24] [0, 3, 4, 3, 2, 2, -1]
# False
# False
# False
#
# 0
# [19, 19, 21, 25, 28, 29, 29] [0, 2, 4, 3, 1, 0]
# False
# False
# False
#
# 0
# [78, 78, 82, 85, 86, 88, 90, 94] [0, 4, 3, 1, 2, 2, 4]
# False
# False
# False
#
# 0
# [61, 61, 63, 67, 68, 75] [0, 2, 4, 1, 7]
# False
# False
# False
#
# 0
# [23, 23, 28, 29, 31] [0, 5, 1, 2]
# False
# False
# False
#
# 0
# [31, 31, 38, 40, 38] [0, 7, 2, -2]
# False
# False
# False
#
# 0
# [84, 84, 89, 90, 92, 95, 96, 96] [0, 5, 1, 2, 3, 1, 0]
# False
# False
# False
#
# 0
# [32, 32, 33, 38, 42] [0, 1, 5, 4]
# False
# False
# False
#
# 0
# [32, 32, 33, 34, 37, 42, 47] [0, 1, 1, 3, 5, 5]
# False
# False
# False
#
# 0
# [49, 53, 56, 58, 61, 64, 66] [4, 3, 2, 3, 3, 2]
# False
# True
# False
#
# 0
# [54, 58, 61, 62, 65, 66, 65] [4, 3, 1, 3, 1, -1]
# False
# False
# False
#
# 0
# [21, 25, 27, 30, 30] [4, 2, 3, 0]
# False
# False
# False
#
# 0
# [42, 46, 49, 50, 51, 55] [4, 3, 1, 1, 4]
# False
# True
# False
#
# 0
# [58, 62, 63, 65, 66, 69, 72, 78] [4, 1, 2, 1, 3, 3, 6]
# False
# True
# False
#
# 0
# [89, 93, 96, 94, 96] [4, 3, -2, 2]
# False
# False
# False
#
# 0
# [36, 40, 37, 39, 42, 44, 47, 46] [4, -3, 2, 3, 2, 3, -1]
# False
# False
# False
#
# 0
# [81, 85, 86, 85, 88, 91, 91] [4, 1, -1, 3, 3, 0]
# False
# False
# False
#
# 0
# [15, 19, 20, 18, 19, 20, 21, 25] [4, 1, -2, 1, 1, 1, 4]
# False
# False
# False
#
# 0
# [75, 79, 78, 80, 86] [4, -1, 2, 6]
# False
# False
# False
#
# 0
# [25, 29, 32, 34, 37, 37, 40, 43] [4, 3, 2, 3, 0, 3, 3]
# False
# False
# False
#
# 0
# [42, 46, 49, 52, 55, 58, 58, 57] [4, 3, 3, 3, 3, 0, -1]
# False
# False
# False
#
# 0
# [5, 9, 11, 13, 13, 16, 17, 17] [4, 2, 2, 0, 3, 1, 0]
# False
# False
# False
#
# 0
# [83, 87, 87, 90, 91, 93, 97] [4, 0, 3, 1, 2, 4]
# False
# False
# False
#
# 0
# [19, 23, 24, 27, 27, 30, 36] [4, 1, 3, 0, 3, 6]
# False
# False
# False
#
# 0
# [18, 22, 23, 27, 29] [4, 1, 4, 2]
# False
# True
# False
#
# 0
# [8, 12, 13, 14, 18, 16] [4, 1, 1, 4, -2]
# False
# False
# False
#
# 0
# [19, 23, 25, 29, 29] [4, 2, 4, 0]
# False
# False
# False
#
# 0
# [60, 64, 65, 69, 72, 73, 76, 80] [4, 1, 4, 3, 1, 3, 4]
# False
# True
# False
#
# 0
# [29, 33, 34, 38, 39, 44] [4, 1, 4, 1, 5]
# False
# True
# False
#
# 0
# [64, 68, 69, 70, 72, 78, 80] [4, 1, 1, 2, 6, 2]
# False
# True
# False
#
# 0
# [8, 12, 15, 18, 25, 26, 25] [4, 3, 3, 7, 1, -1]
# False
# False
# False
#
# 0
# [39, 43, 46, 47, 52, 52] [4, 3, 1, 5, 0]
# False
# False
# False
#
# 0
# [41, 45, 47, 54, 58] [4, 2, 7, 4]
# False
# True
# False
#
# 0
# [3, 7, 12, 14, 15, 22] [4, 5, 2, 1, 7]
# False
# True
# False
#
# 0
# [22, 27, 28, 30, 32] [5, 1, 2, 2]
# False
# True
# False
#
# 0
# [3, 10, 13, 15, 16, 15] [7, 3, 2, 1, -1]
# False
# False
# False
#
# 0
# [44, 49, 51, 53, 53] [5, 2, 2, 0]
# False
# False
# False
#
# 0
# [1, 7, 9, 10, 11, 12, 13, 17] [6, 2, 1, 1, 1, 1, 4]
# False
# True
# False
#
# 0
# [16, 21, 24, 25, 30] [5, 3, 1, 5]
# False
# True
# False
#
# 0
# [24, 29, 30, 29, 31, 33] [5, 1, -1, 2, 2]
# False
# False
# False
#
# 0
# [39, 46, 49, 47, 50, 51, 49] [7, 3, -2, 3, 1, -2]
# False
# False
# False
#
# 0
# [20, 25, 23, 26, 26] [5, -2, 3, 0]
# False
# False
# False
#
# 0
# [39, 46, 47, 49, 48, 50, 54] [7, 1, 2, -1, 2, 4]
# False
# False
# False
#
# 0
# [18, 24, 25, 27, 26, 31] [6, 1, 2, -1, 5]
# False
# False
# False
#
# 0
# [13, 18, 21, 21, 23, 24, 27] [5, 3, 0, 2, 1, 3]
# False
# False
# False
#
# 0
# [32, 37, 38, 38, 40, 43, 40] [5, 1, 0, 2, 3, -3]
# False
# False
# False
#
# 0
# [39, 46, 48, 50, 52, 52, 52] [7, 2, 2, 2, 0, 0]
# False
# False
# False
#
# 0
# [35, 40, 42, 43, 43, 46, 49, 53] [5, 2, 1, 0, 3, 3, 4]
# False
# False
# False
#
# 0
# [41, 48, 48, 51, 53, 60] [7, 0, 3, 2, 7]
# False
# False
# False
#
# 0
# [11, 17, 20, 24, 26, 28] [6, 3, 4, 2, 2]
# False
# True
# False
#
# 0
# [6, 13, 15, 19, 16] [7, 2, 4, -3]
# False
# False
# False
#
# 0
# [80, 86, 88, 92, 95, 96, 98, 98] [6, 2, 4, 3, 1, 2, 0]
# False
# False
# False
#
# 0
# [73, 79, 80, 84, 86, 90] [6, 1, 4, 2, 4]
# False
# True
# False
#
# 0
# [69, 74, 77, 81, 82, 85, 91] [5, 3, 4, 1, 3, 6]
# False
# True
# False
#
# 0
# [16, 23, 24, 27, 32, 34, 36, 39] [7, 1, 3, 5, 2, 2, 3]
# False
# True
# False
#
# 0
# [56, 62, 65, 71, 74, 73] [6, 3, 6, 3, -1]
# False
# False
# False
#
# 0
# [59, 66, 67, 72, 72] [7, 1, 5, 0]
# False
# False
# False
#
# 0
# [11, 17, 20, 23, 29, 30, 33, 37] [6, 3, 3, 6, 1, 3, 4]
# False
# True
# False
#
# 0
# [40, 46, 48, 51, 58, 65] [6, 2, 3, 7, 7]
# False
# True
# False
#
# 0
# [57, 55, 54, 51, 49, 48, 46, 47] [-2, -1, -3, -2, -1, -2, 1]
# True
# False
# False
#
# 0
# [6, 5, 2, 1, 1] [-1, -3, -1, 0]
# False
# False
# False
#
# 0
# [88, 86, 84, 83, 80, 79, 75] [-2, -2, -1, -3, -1, -4]
# False
# True
# False
#
# 0
# [71, 70, 67, 66, 60] [-1, -3, -1, -6]
# False
# True
# False
#
# 0
# [46, 45, 43, 40, 42, 39, 36] [-1, -2, -3, 2, -3, -3]
# True
# False
# False
#
# 0
# [21, 19, 17, 20, 17, 20] [-2, -2, 3, -3, 3]
# True
# False
# False
#
# 0
# [56, 55, 52, 54, 53, 53] [-1, -3, 2, -1, 0]
# False
# False
# False
#
# 0
# [76, 75, 77, 76, 73, 71, 67] [-1, 2, -1, -3, -2, -4]
# False
# False
# False
#
# 0
# [55, 54, 53, 56, 51] [-1, -1, 3, -5]
# False
# False
# False
#
# 0
# [86, 84, 82, 82, 80, 79] [-2, -2, 0, -2, -1]
# False
# False
# False
#
# 0
# [28, 25, 23, 21, 21, 19, 17, 18] [-3, -2, -2, 0, -2, -2, 1]
# False
# False
# False
#
# 0
# [91, 88, 85, 85, 85] [-3, -3, 0, 0]
# False
# False
# False
#
# 0
# [83, 82, 79, 78, 78, 74] [-1, -3, -1, 0, -4]
# False
# False
# False
#
# 0
# [43, 40, 40, 38, 31] [-3, 0, -2, -7]
# False
# False
# False
#
# 0
# [69, 68, 66, 65, 64, 60, 58, 57] [-1, -2, -1, -1, -4, -2, -1]
# False
# True
# False
#
# 0
# [77, 76, 74, 72, 70, 69, 65, 66] [-1, -2, -2, -2, -1, -4, 1]
# False
# False
# False
#
# 0
# [71, 70, 69, 65, 65] [-1, -1, -4, 0]
# False
# False
# False
#
# 0
# [60, 57, 54, 52, 48, 46, 45, 41] [-3, -3, -2, -4, -2, -1, -4]
# False
# True
# False
#
# 0
# [83, 80, 78, 76, 72, 66] [-3, -2, -2, -4, -6]
# False
# True
# False
#
# 0
# [86, 83, 76, 73, 72, 71] [-3, -7, -3, -1, -1]
# False
# True
# False
#
# 0
# [80, 79, 77, 75, 74, 68, 65, 66] [-1, -2, -2, -1, -6, -3, 1]
# False
# False
# False
#
# 0
# [53, 50, 49, 47, 44, 38, 37, 37] [-3, -1, -2, -3, -6, -1, 0]
# False
# False
# False
#
# 0
# [27, 24, 21, 14, 12, 10, 6] [-3, -3, -7, -2, -2, -4]
# False
# True
# False
#
# 0
# [51, 50, 45, 43, 41, 34] [-1, -5, -2, -2, -7]
# False
# True
# False
#
# 0
# [45, 46, 44, 41, 40, 39, 36] [1, -2, -3, -1, -1, -3]
# True
# False
# False
#
# 0
# [82, 84, 83, 80, 78, 77, 74, 75] [2, -1, -3, -2, -1, -3, 1]
# True
# False
# False
#
# 0
# [45, 46, 43, 42, 39, 37, 37] [1, -3, -1, -3, -2, 0]
# False
# False
# False
#
# 0
# [39, 42, 41, 39, 37, 34, 30] [3, -1, -2, -2, -3, -4]
# False
# False
# False
#
# 0
# [73, 76, 74, 71, 70, 69, 62] [3, -2, -3, -1, -1, -7]
# False
# False
# False
#
# 0
# [13, 16, 19, 18, 17, 16] [3, 3, -1, -1, -1]
# True
# False
# False
#
# 0
# [18, 19, 18, 17, 16, 18, 15, 18] [1, -1, -1, -1, 2, -3, 3]
# True
# False
# False
#
# 0
# [11, 13, 11, 13, 12, 12] [2, -2, 2, -1, 0]
# False
# False
# False
#
# 0
# [19, 22, 21, 23, 19] [3, -1, 2, -4]
# False
# False
# False
#
# 0
# [83, 85, 84, 87, 81] [2, -1, 3, -6]
# False
# False
# False
#
# 0
# [75, 77, 74, 74, 72, 70] [2, -3, 0, -2, -2]
# False
# False
# False
#
# 0
# [22, 25, 25, 22, 20, 18, 15, 17] [3, 0, -3, -2, -2, -3, 2]
# False
# False
# False
#
# 0
# [11, 14, 11, 11, 11] [3, -3, 0, 0]
# False
# False
# False
#
# 0
# [93, 94, 92, 89, 89, 88, 87, 83] [1, -2, -3, 0, -1, -1, -4]
# False
# False
# False
#
# 0
# [16, 18, 16, 16, 15, 9] [2, -2, 0, -1, -6]
# False
# False
# False
#
# 0
# [25, 27, 26, 22, 19, 18, 15, 13] [2, -1, -4, -3, -1, -3, -2]
# False
# False
# False
#
# 0
# [77, 78, 76, 72, 71, 69, 66, 67] [1, -2, -4, -1, -2, -3, 1]
# False
# False
# False
#
# 0
# [94, 96, 95, 93, 89, 89] [2, -1, -2, -4, 0]
# False
# False
# False
#
# 0
# [31, 32, 31, 28, 24, 22, 21, 17] [1, -1, -3, -4, -2, -1, -4]
# False
# False
# False
#
# 0
# [36, 39, 38, 35, 33, 29, 23] [3, -1, -3, -2, -4, -6]
# False
# False
# False
#
# 0
# [28, 29, 26, 25, 20, 17] [1, -3, -1, -5, -3]
# False
# False
# False
#
# 0
# [60, 63, 61, 59, 54, 52, 55] [3, -2, -2, -5, -2, 3]
# False
# False
# False
#
# 0
# [54, 57, 55, 54, 53, 48, 48] [3, -2, -1, -1, -5, 0]
# False
# False
# False
#
# 0
# [32, 35, 28, 26, 22] [3, -7, -2, -4]
# False
# False
# False
#
# 0
# [34, 36, 34, 32, 29, 23, 22, 17] [2, -2, -2, -3, -6, -1, -5]
# False
# False
# False
#
# 0
# [71, 71, 68, 65, 63, 61, 58] [0, -3, -3, -2, -2, -3]
# False
# False
# False
#
# 0
# [30, 30, 27, 26, 24, 21, 22] [0, -3, -1, -2, -3, 1]
# False
# False
# False
#
# 0
# [12, 12, 11, 9, 6, 4, 3, 3] [0, -1, -2, -3, -2, -1, 0]
# False
# False
# False
#
# 0
# [17, 17, 14, 12, 10, 8, 6, 2] [0, -3, -2, -2, -2, -2, -4]
# False
# False
# False
#
# 0
# [64, 64, 62, 60, 57, 55, 48] [0, -2, -2, -3, -2, -7]
# False
# False
# False
#
# 0
# [87, 87, 84, 87, 86, 85] [0, -3, 3, -1, -1]
# False
# False
# False
#
# 0
# [55, 55, 54, 55, 53, 50, 52] [0, -1, 1, -2, -3, 2]
# False
# False
# False
#
# 0
# [54, 54, 51, 48, 49, 48, 46, 46] [0, -3, -3, 1, -1, -2, 0]
# False
# False
# False
#
# 0
# [35, 35, 32, 29, 26, 23, 26, 22] [0, -3, -3, -3, -3, 3, -4]
# False
# False
# False
#
# 0
# [10, 10, 9, 11, 9, 2] [0, -1, 2, -2, -7]
# False
# False
# False
#
# 0
# [40, 40, 37, 36, 36, 33] [0, -3, -1, 0, -3]
# False
# False
# False
#
# 0
# [34, 34, 33, 33, 30, 33] [0, -1, 0, -3, 3]
# False
# False
# False
#
# 0
# [67, 67, 65, 63, 60, 58, 58, 58] [0, -2, -2, -3, -2, 0, 0]
# False
# False
# False
#
# 0
# [15, 15, 14, 14, 12, 10, 6] [0, -1, 0, -2, -2, -4]
# False
# False
# False
#
# 0
# [74, 74, 72, 71, 71, 65] [0, -2, -1, 0, -6]
# False
# False
# False
#
# 0
# [48, 48, 45, 41, 39, 36, 33] [0, -3, -4, -2, -3, -3]
# False
# False
# False
#
# 0
# [31, 31, 27, 26, 27] [0, -4, -1, 1]
# False
# False
# False
#
# 0
# [54, 54, 50, 48, 46, 46] [0, -4, -2, -2, 0]
# False
# False
# False
#
# 0
# [62, 62, 59, 55, 52, 48] [0, -3, -4, -3, -4]
# False
# False
# False
#
# 0
# [49, 49, 45, 42, 41, 36] [0, -4, -3, -1, -5]
# False
# False
# False
#
# 0
# [95, 95, 89, 87, 86, 84, 82, 79] [0, -6, -2, -1, -2, -2, -3]
# False
# False
# False
#
# 0
# [52, 52, 50, 48, 43, 46] [0, -2, -2, -5, 3]
# False
# False
# False
#
# 0
# [37, 37, 34, 33, 32, 30, 23, 23] [0, -3, -1, -1, -2, -7, 0]
# False
# False
# False
#
# 0
# [89, 89, 86, 80, 77, 73] [0, -3, -6, -3, -4]
# False
# False
# False
#
# 0
# [69, 69, 67, 60, 55] [0, -2, -7, -5]
# False
# False
# False
#
# 0
# [25, 21, 19, 17, 16, 15] [-4, -2, -2, -1, -1]
# False
# True
# False
#
# 0
# [80, 76, 75, 74, 72, 71, 73] [-4, -1, -1, -2, -1, 2]
# False
# False
# False
#
# 0
# [18, 14, 12, 9, 6, 5, 4, 4] [-4, -2, -3, -3, -1, -1, 0]
# False
# False
# False
#
# 0
# [89, 85, 82, 79, 76, 73, 70, 66] [-4, -3, -3, -3, -3, -3, -4]
# False
# True
# False
#
# 0
# [78, 74, 72, 71, 70, 64] [-4, -2, -1, -1, -6]
# False
# True
# False
#
# 0
# [50, 46, 45, 43, 45, 44, 42, 39] [-4, -1, -2, 2, -1, -2, -3]
# False
# False
# False
#
# 0
# [81, 77, 74, 75, 73, 71, 74] [-4, -3, 1, -2, -2, 3]
# False
# False
# False
#
# 0
# [78, 74, 75, 72, 69, 66, 66] [-4, 1, -3, -3, -3, 0]
# False
# False
# False
#
# 0
# [59, 55, 54, 53, 50, 47, 50, 46] [-4, -1, -1, -3, -3, 3, -4]
# False
# False
# False
#
# 0
# [49, 45, 42, 39, 40, 37, 36, 30] [-4, -3, -3, 1, -3, -1, -6]
# False
# False
# False
#
# 0
# [94, 90, 87, 85, 83, 82, 82, 80] [-4, -3, -2, -2, -1, 0, -2]
# False
# False
# False
#
# 0
# [15, 11, 8, 8, 9] [-4, -3, 0, 1]
# False
# False
# False
#
# 0
# [24, 20, 19, 16, 13, 12, 12, 12] [-4, -1, -3, -3, -1, 0, 0]
# False
# False
# False
#
# 0
# [57, 53, 51, 49, 48, 47, 47, 43] [-4, -2, -2, -1, -1, 0, -4]
# False
# False
# False
#
# 0
# [66, 62, 61, 59, 59, 57, 52] [-4, -1, -2, 0, -2, -5]
# False
# False
# False
#
# 0
# [73, 69, 67, 65, 61, 60] [-4, -2, -2, -4, -1]
# False
# True
# False
#
# 0
# [98, 94, 91, 90, 86, 83, 86] [-4, -3, -1, -4, -3, 3]
# False
# False
# False
#
# 0
# [73, 69, 65, 63, 63] [-4, -4, -2, 0]
# False
# False
# False
#
# 0
# [24, 20, 19, 15, 11] [-4, -1, -4, -4]
# False
# True
# False
#
# 0
# [99, 95, 93, 92, 88, 87, 81] [-4, -2, -1, -4, -1, -6]
# False
# True
# False
#
# 0
# [89, 85, 82, 77, 76] [-4, -3, -5, -1]
# False
# True
# False
#
# 0
# [30, 26, 20, 19, 18, 19] [-4, -6, -1, -1, 1]
# False
# False
# False
#
# 0
# [49, 45, 44, 42, 39, 34, 34] [-4, -1, -2, -3, -5, 0]
# False
# False
# False
#
# 0
# [39, 35, 34, 31, 26, 23, 19] [-4, -1, -3, -5, -3, -4]
# False
# True
# False
#
# 0
# [60, 56, 54, 49, 46, 40] [-4, -2, -5, -3, -6]
# False
# True
# False
#
# 0
# [53, 47, 44, 43, 40, 39] [-6, -3, -1, -3, -1]
# False
# True
# False
#
# 0
# [23, 18, 16, 13, 12, 10, 9, 11] [-5, -2, -3, -1, -2, -1, 2]
# False
# False
# False
#
# 0
# [99, 92, 90, 87, 85, 84, 81, 81] [-7, -2, -3, -2, -1, -3, 0]
# False
# False
# False
#
# 0
# [35, 30, 29, 27, 26, 23, 21, 17] [-5, -1, -2, -1, -3, -2, -4]
# False
# True
# False
#
# 0
# [20, 15, 14, 13, 10, 5] [-5, -1, -1, -3, -5]
# False
# True
# False
#
# 0
# [23, 16, 15, 14, 16, 14, 12] [-7, -1, -1, 2, -2, -2]
# False
# False
# False
#
# 0
# [53, 48, 46, 48, 45, 43, 45] [-5, -2, 2, -3, -2, 2]
# False
# False
# False
#
# 0
# [9, 4, 1, 2, 2] [-5, -3, 1, 0]
# False
# False
# False
#
# 0
# [55, 49, 51, 49, 46, 42] [-6, 2, -2, -3, -4]
# False
# False
# False
#
# 0
# [75, 68, 65, 62, 60, 62, 60, 53] [-7, -3, -3, -2, 2, -2, -7]
# False
# False
# False
#
# 0
# [71, 65, 62, 59, 59, 58, 55, 53] [-6, -3, -3, 0, -1, -3, -2]
# False
# False
# False
#
# 0
# [24, 17, 14, 13, 13, 14] [-7, -3, -1, 0, 1]
# False
# False
# False
#
# 0
# [12, 6, 6, 4, 4] [-6, 0, -2, 0]
# False
# False
# False
#
# 0
# [44, 37, 35, 32, 32, 29, 26, 22] [-7, -2, -3, 0, -3, -3, -4]
# False
# False
# False
#
# 0
# [30, 24, 24, 23, 22, 20, 15] [-6, 0, -1, -1, -2, -5]
# False
# False
# False
#
# 0
# [45, 39, 37, 36, 32, 29] [-6, -2, -1, -4, -3]
# False
# True
# False
#
# 0
# [27, 20, 19, 15, 13, 10, 8, 9] [-7, -1, -4, -2, -3, -2, 1]
# False
# False
# False
#
# 0
# [83, 76, 72, 70, 70] [-7, -4, -2, 0]
# False
# False
# False
#
# 0
# [52, 45, 43, 39, 37, 36, 32] [-7, -2, -4, -2, -1, -4]
# False
# True
# False
#
# 0
# [58, 51, 47, 45, 42, 39, 33] [-7, -4, -2, -3, -3, -6]
# False
# True
# False
#
# 0
# [51, 46, 43, 41, 34, 33, 30] [-5, -3, -2, -7, -1, -3]
# False
# True
# False
#
# 0
# [55, 49, 48, 41, 43] [-6, -1, -7, 2]
# False
# False
# False
#
# 0
# [20, 13, 11, 4, 3, 1, 1] [-7, -2, -7, -1, -2, 0]
# False
# False
# False
#
# 0
# [84, 77, 76, 74, 67, 64, 63, 59] [-7, -1, -2, -7, -3, -1, -4]
# False
# True
# False
#
# 0
# [85, 78, 76, 75, 73, 68, 67, 60] [-7, -2, -1, -2, -5, -1, -7]
# False
# True
# False
#
# 0
# [75, 71, 71, 68, 71] [-4, 0, -3, 3]
# False
# False
# False
#
# 0
# [87, 87, 84, 83, 80, 83, 77] [0, -3, -1, -3, 3, -6]
# False
# False
# False
#
# 0
# [17, 22, 24, 26, 27, 26, 28, 33] [5, 2, 2, 1, -1, 2, 5]
# False
# False
# False
#
# 0
# [65, 61, 60, 60, 57] [-4, -1, 0, -3]
# False
# False
# False
#
# 0
# [19, 20, 17, 16, 15, 15] [1, -3, -1, -1, 0]
# False
# False
# False
#
# 0
# [46, 46, 44, 43, 42, 39, 37, 33] [0, -2, -1, -1, -3, -2, -4]
# False
# False
# False
#
# 0
# [83, 83, 83, 85, 86, 89, 90, 94] [0, 0, 2, 1, 3, 1, 4]
# False
# False
# False
#
# 0
# [46, 52, 55, 60, 67] [6, 3, 5, 7]
# False
# True
# False
#
# 0
# [98, 91, 90, 87, 84, 84] [-7, -1, -3, -3, 0]
# False
# False
# False
#
# 0
# [87, 88, 84, 81, 80, 79, 73] [1, -4, -3, -1, -1, -6]
# False
# False
# False
#
# 0
# [4, 6, 8, 9, 6, 9, 8] [2, 2, 1, -3, 3, -1]
# True
# False
# False
#
# 0
# [59, 59, 56, 53, 55, 52] [0, -3, -3, 2, -3]
# False
# False
# False
#
# 0
# [31, 31, 33, 30, 33] [0, 2, -3, 3]
# False
# False
# False
#
# 0
# [40, 38, 35, 31, 29, 27] [-2, -3, -4, -2, -2]
# False
# True
# False
#
# 0
# [92, 90, 87, 84, 77, 76, 75, 78] [-2, -3, -3, -7, -1, -1, 3]
# False
# False
# False
#
# 0
# [26, 27, 27, 30, 33, 36, 40] [1, 0, 3, 3, 3, 4]
# False
# False
# False
#
# 0
# [42, 38, 36, 33, 34, 32] [-4, -2, -3, 1, -2]
# False
# False
# False
#
# 0
# [79, 73, 72, 72, 69, 72] [-6, -1, 0, -3, 3]
# False
# False
# False
#
# 0
# [57, 57, 51, 49, 47, 44, 40] [0, -6, -2, -2, -3, -4]
# False
# False
# False
#
# 0
# [47, 53, 56, 58, 62, 62] [6, 3, 2, 4, 0]
# False
# False
# False
#
# 0
# [27, 27, 29, 34, 36, 37, 38] [0, 2, 5, 2, 1, 1]
# False
# False
# False
#
# 0
# [49, 49, 51, 51, 51] [0, 2, 0, 0]
# False
# False
# False
#
# 0
# [49, 53, 57, 59, 61, 65] [4, 4, 2, 2, 4]
# False
# True
# False
#
# 0
# [90, 92, 93, 90, 97] [2, 1, -3, 7]
# False
# False
# False
#
# 0
# [40, 36, 32, 30, 26] [-4, -4, -2, -4]
# False
# True
# False
#
# 0
# [94, 90, 88, 85, 85] [-4, -2, -3, 0]
# False
# False
# False
#
# 0
# [39, 39, 36, 34, 27, 24, 23, 26] [0, -3, -2, -7, -3, -1, 3]
# False
# False
# False
#
# 0
# [47, 45, 43, 42, 45, 43, 41, 37] [-2, -2, -1, 3, -2, -2, -4]
# False
# False
# False
#
# 0
# [30, 34, 37, 38, 40, 43, 46, 45] [4, 3, 1, 2, 3, 3, -1]
# False
# False
# False
#
# 0
# [70, 70, 72, 75, 79, 82, 86] [0, 2, 3, 4, 3, 4]
# False
# False
# False
#
# 0
# [99, 96, 95, 94, 97, 94, 87] [-3, -1, -1, 3, -3, -7]
# False
# False
# False
#
# 0
# [69, 72, 71, 68, 61] [3, -1, -3, -7]
# False
# False
# False
#
# 0
# [80, 73, 76, 73, 72, 69, 65] [-7, 3, -3, -1, -3, -4]
# False
# False
# False
#
# 0
# [94, 94, 93, 87, 87] [0, -1, -6, 0]
# False
# False
# False
#
# 0
# [51, 51, 52, 53, 56, 62] [0, 1, 1, 3, 6]
# False
# False
# False
#
# 0
# [46, 42, 40, 37, 35, 31] [-4, -2, -3, -2, -4]
# False
# True
# False
#
# 0
# [63, 63, 61, 60, 57, 56, 54, 54] [0, -2, -1, -3, -1, -2, 0]
# False
# False
# False
#
# 0
# [45, 43, 41, 37, 35, 34, 31, 25] [-2, -2, -4, -2, -1, -3, -6]
# False
# True
# False
#
# 0
# [36, 36, 36, 37, 40, 47] [0, 0, 1, 3, 7]
# False
# False
# False
#
# 0
# [94, 88, 87, 83, 82, 80, 80] [-6, -1, -4, -1, -2, 0]
# False
# False
# False
#
# 0
# [62, 66, 69, 73, 76] [4, 3, 4, 3]
# False
# True
# False
#
# 0
# [37, 40, 34, 32, 30, 24] [3, -6, -2, -2, -6]
# False
# False
# False
#
# 0
# [21, 14, 7, 6, 4] [-7, -7, -1, -2]
# False
# True
# False
#
# 0
# [41, 42, 45, 48, 49, 52, 54, 58] [1, 3, 3, 1, 3, 2, 4]
# False
# True
# False
#
# 0
# [19, 26, 32, 33, 34, 34] [7, 6, 1, 1, 0]
# False
# False
# False
#
# 0
# [37, 38, 41, 42, 43, 43, 46] [1, 3, 1, 1, 0, 3]
# False
# False
# False
#
# 0
# [82, 86, 83, 86, 89, 92, 95, 99] [4, -3, 3, 3, 3, 3, 4]
# False
# False
# False
#
# 0
# [43, 38, 36, 35, 33, 30, 28] [-5, -2, -1, -2, -3, -2]
# False
# True
# False
#
# 0
# [18, 17, 13, 11, 13] [-1, -4, -2, 2]
# False
# False
# False
#
# 0
# [92, 93, 90, 92, 91, 90, 85] [1, -3, 2, -1, -1, -5]
# False
# False
# False
#
# 0
# [80, 80, 78, 76, 74, 77] [0, -2, -2, -2, 3]
# False
# False
# False
#
# 0
# [19, 22, 24, 30, 32, 39] [3, 2, 6, 2, 7]
# False
# True
# False
#
# 0
# [76, 71, 69, 66, 65, 64, 61, 55] [-5, -2, -3, -1, -1, -3, -6]
# False
# True
# False
#
# 0
# [14, 17, 15, 12, 11, 5, 5] [3, -2, -3, -1, -6, 0]
# False
# False
# False
#
# 0
# [69, 70, 71, 72, 72, 69] [1, 1, 1, 0, -3]
# False
# False
# False
#
# 0
# [39, 39, 40, 38, 39, 39] [0, 1, -2, 1, 0]
# False
# False
# False
#
# 0
# [54, 57, 60, 62, 63, 66, 66] [3, 3, 2, 1, 3, 0]
# False
# False
# False
#
# 0
# [60, 56, 54, 53, 50, 48, 45, 47] [-4, -2, -1, -3, -2, -3, 2]
# False
# False
# False
#
# 0
# [55, 49, 51, 50, 47] [-6, 2, -1, -3]
# False
# False
# False
#
# 0
# [88, 88, 92, 95, 92] [0, 4, 3, -3]
# False
# False
# False
#
# 0
# [50, 52, 56, 58, 59, 63] [2, 4, 2, 1, 4]
# False
# True
# False
#
# 0
# [22, 22, 24, 25, 29, 31, 33] [0, 2, 1, 4, 2, 2]
# False
# False
# False
#
# 0
# [7, 6, 9, 11, 17, 18, 21, 28] [-1, 3, 2, 6, 1, 3, 7]
# False
# False
# False
#
# 0
# [70, 68, 72, 74, 75, 78] [-2, 4, 2, 1, 3]
# False
# False
# False
#
# 0
# [60, 63, 61, 60, 57, 55, 51] [3, -2, -1, -3, -2, -4]
# False
# False
# False
#
# 0
# [20, 17, 20, 21, 24, 31, 34, 32] [-3, 3, 1, 3, 7, 3, -2]
# False
# False
# False
#
# 0
# [3, 9, 10, 12, 16, 17, 20, 21] [6, 1, 2, 4, 1, 3, 1]
# False
# True
# False
#
# 0
# [89, 88, 90, 92, 92, 94, 95, 97] [-1, 2, 2, 0, 2, 1, 2]
# False
# False
# False
#
# 0
# [99, 98, 95, 93, 94] [-1, -3, -2, 1]
# True
# False
# False
#
# 0
# [59, 64, 67, 68, 67, 67] [5, 3, 1, -1, 0]
# False
# False
# False
#
# 0
# [90, 83, 82, 79, 74, 73, 66] [-7, -1, -3, -5, -1, -7]
# False
# True
# False
#
# 0
# [34, 34, 39, 42, 42] [0, 5, 3, 0]
# False
# False
# False
#
# 0
# [61, 61, 60, 58, 55, 52, 48, 43] [0, -1, -2, -3, -3, -4, -5]
# False
# False
# False
#
# 0
# [62, 67, 73, 75, 73] [5, 6, 2, -2]
# False
# False
# False
#
# 0
# [74, 78, 78, 80, 82, 86] [4, 0, 2, 2, 4]
# False
# False
# False
#
# 0
# [36, 37, 37, 36, 31] [1, 0, -1, -5]
# False
# False
# False
#
# 0
# [41, 41, 38, 38, 38] [0, -3, 0, 0]
# False
# False
# False
#
# 0
# [7, 11, 12, 9, 12, 13, 16, 23] [4, 1, -3, 3, 1, 3, 7]
# False
# False
# False
#
# 0
# [99, 95, 92, 90, 88, 82, 79, 81] [-4, -3, -2, -2, -6, -3, 2]
# False
# False
# False
#
# 0
# [7, 8, 11, 10, 13] [1, 3, -1, 3]
# True
# False
# False
#
# 0
# [13, 17, 19, 22, 23, 27] [4, 2, 3, 1, 4]
# False
# True
# False
#
# 0
# [17, 15, 13, 13, 8] [-2, -2, 0, -5]
# False
# False
# False
#
# 0
# [56, 51, 49, 49, 47, 47] [-5, -2, 0, -2, 0]
# False
# False
# False
#
# 0
# [35, 39, 42, 45, 42, 45] [4, 3, 3, -3, 3]
# False
# False
# False
#
# 0
# [59, 59, 66, 67, 71] [0, 7, 1, 4]
# False
# False
# False
#
# 0
# [48, 50, 50, 51, 51] [2, 0, 1, 0]
# False
# False
# False
#
# 0
# [82, 79, 82, 85, 89, 96] [-3, 3, 3, 4, 7]
# False
# False
# False
#
# 0
# [81, 81, 77, 75, 72] [0, -4, -2, -3]
# False
# False
# False
#
# 0
# [25, 20, 19, 19, 17] [-5, -1, 0, -2]
# False
# False
# False
#
# 0
# [59, 59, 61, 65, 67, 74] [0, 2, 4, 2, 7]
# False
# False
# False
#
# 0
# [5, 6, 13, 16, 19, 19] [1, 7, 3, 3, 0]
# False
# False
# False
#
# 0
# [59, 62, 65, 67, 70, 74, 76, 76] [3, 3, 2, 3, 4, 2, 0]
# False
# False
# False
#
# 0
# [46, 50, 51, 52, 53, 57, 58, 63] [4, 1, 1, 1, 4, 1, 5]
# False
# True
# False
#
# 0
# [6, 3, 6, 8, 10, 10] [-3, 3, 2, 2, 0]
# False
# False
# False
#
# 0
# [82, 75, 71, 70, 67, 64, 62, 58] [-7, -4, -1, -3, -3, -2, -4]
# False
# True
# False
#
# 0
# [46, 46, 46, 43, 40, 36] [0, 0, -3, -3, -4]
# False
# False
# False
#
# 0
# [9, 13, 15, 17, 24, 25, 32] [4, 2, 2, 7, 1, 7]
# False
# True
# False
#
# 0
# [48, 47, 44, 42, 41, 38, 37, 37] [-1, -3, -2, -1, -3, -1, 0]
# False
# False
# False
#
# 0
# [19, 25, 26, 31, 33, 35] [6, 1, 5, 2, 2]
# False
# True
# False
#
# 0
# [29, 26, 27, 29, 31, 34] [-3, 1, 2, 2, 3]
# True
# False
# False
#
# 0
# [38, 38, 35, 33, 30, 28, 31, 27] [0, -3, -2, -3, -2, 3, -4]
# False
# False
# False
#
# 0
# [10, 10, 16, 18, 19, 20, 17] [0, 6, 2, 1, 1, -3]
# False
# False
# False
#
# 0
# [74, 74, 70, 67, 66, 64, 65] [0, -4, -3, -1, -2, 1]
# False
# False
# False
#
# 0
# [34, 30, 28, 28, 25, 23, 20, 16] [-4, -2, 0, -3, -2, -3, -4]
# False
# False
# False
#
# 0
# [38, 38, 35, 37, 40, 38] [0, -3, 2, 3, -2]
# False
# False
# False
#
# 0
# [43, 42, 48, 51, 53, 53] [-1, 6, 3, 2, 0]
# False
# False
# False
#
# 0
# [66, 67, 69, 72, 74, 81] [1, 2, 3, 2, 7]
# False
# True
# False
#
# 0
# [3, 7, 9, 10, 11, 16] [4, 2, 1, 1, 5]
# False
# True
# False
#
# 0
# [49, 48, 46, 43, 41, 40, 38, 31] [-1, -2, -3, -2, -1, -2, -7]
# False
# True
# False
#
# 0
# [17, 14, 16, 20, 18] [-3, 2, 4, -2]
# False
# False
# False
#
# 0
# [72, 68, 65, 63, 62, 59, 62, 62] [-4, -3, -2, -1, -3, 3, 0]
# False
# False
# False
#
# 0
# [69, 65, 61, 60, 63] [-4, -4, -1, 3]
# False
# False
# False
#
# 0
# [17, 16, 18, 21, 21, 23, 25, 32] [-1, 2, 3, 0, 2, 2, 7]
# False
# False
# False
#
# 0
# [28, 25, 25, 23, 24] [-3, 0, -2, 1]
# False
# False
# False
#
# 0
# [41, 41, 42, 45, 46, 49, 53] [0, 1, 3, 1, 3, 4]
# False
# False
# False
#
# 0
# [98, 95, 92, 90, 90, 89] [-3, -3, -2, 0, -1]
# False
# False
# False
#
# 0
# [68, 71, 70, 73, 70, 66] [3, -1, 3, -3, -4]
# False
# False
# False
#
# 0
# [29, 29, 26, 25, 21, 19, 18, 18] [0, -3, -1, -4, -2, -1, 0]
# False
# False
# False
#
# 0
# [62, 62, 60, 58, 58, 57] [0, -2, -2, 0, -1]
# False
# False
# False
#
# 0
# [49, 49, 47, 48, 51] [0, -2, 1, 3]
# False
# False
# False
#
# 0
# [57, 62, 63, 66, 68, 70, 71] [5, 1, 3, 2, 2, 1]
# False
# True
# False
#
# 0
# [7, 5, 9, 10, 13, 14, 17, 17] [-2, 4, 1, 3, 1, 3, 0]
# False
# False
# False
#
# 0
# [85, 90, 93, 95, 95, 92] [5, 3, 2, 0, -3]
# False
# False
# False
#
# 0
# [24, 21, 20, 18, 17, 18, 20] [-3, -1, -2, -1, 1, 2]
# True
# False
# False
#
# 0
# [8, 14, 16, 17, 21] [6, 2, 1, 4]
# False
# True
# False
#
# 0
# [91, 87, 86, 86, 85, 79] [-4, -1, 0, -1, -6]
# False
# False
# False
#
# 0
# [48, 44, 42, 40, 38, 37, 32] [-4, -2, -2, -2, -1, -5]
# False
# True
# False
#
# 0
# [25, 30, 34, 37, 42] [5, 4, 3, 5]
# False
# True
# False
#
# 0
# [25, 19, 13, 11, 7] [-6, -6, -2, -4]
# False
# True
# False
#
# 0
# [55, 55, 52, 51, 44, 43, 42, 41] [0, -3, -1, -7, -1, -1, -1]
# False
# False
# False
#
# 0
# [82, 81, 78, 76, 75, 71] [-1, -3, -2, -1, -4]
# False
# True
# False
#
# 0
# [76, 80, 83, 85, 87, 87, 87] [4, 3, 2, 2, 0, 0]
# False
# False
# False
#
# 0
# [3, 9, 10, 13, 14, 17, 20, 17] [6, 1, 3, 1, 3, 3, -3]
# False
# False
# False
#
# 0
# [23, 26, 27, 29, 31, 34, 32] [3, 1, 2, 2, 3, -2]
# True
# False
# False
#
# 0
# [32, 28, 27, 24, 20, 19, 19] [-4, -1, -3, -4, -1, 0]
# False
# False
# False
#
# 0
# [39, 43, 44, 45, 49, 50, 47] [4, 1, 1, 4, 1, -3]
# False
# False
# False
#
# 0
# [26, 25, 26, 29, 36, 40] [-1, 1, 3, 7, 4]
# False
# False
# False
#
# 0
# [63, 63, 67, 69, 72, 72] [0, 4, 2, 3, 0]
# False
# False
# False
#
# 0
# [69, 76, 77, 79, 82, 86, 89, 87] [7, 1, 2, 3, 4, 3, -2]
# False
# False
# False
#
# 0
# [9, 11, 12, 16, 13] [2, 1, 4, -3]
# False
# False
# False
#
# 0
# [62, 62, 62, 61, 59, 58, 56, 58] [0, 0, -1, -2, -1, -2, 2]
# False
# False
# False
#
# 0
# [24, 26, 25, 24, 24, 21, 19, 19] [2, -1, -1, 0, -3, -2, 0]
# False
# False
# False
#
# 0
# [39, 41, 38, 40, 40] [2, -3, 2, 0]
# False
# False
# False
#
# 0
# [77, 74, 71, 70, 68, 66, 61, 57] [-3, -3, -1, -2, -2, -5, -4]
# False
# True
# False
#
# 0
# [90, 85, 83, 84, 81, 79, 74] [-5, -2, 1, -3, -2, -5]
# False
# False
# False
#
# 0
# [92, 88, 87, 84, 77, 71] [-4, -1, -3, -7, -6]
# False
# True
# False
#
# 0
# [37, 41, 44, 45, 52, 51] [4, 3, 1, 7, -1]
# False
# False
# False
#
# 0
# [55, 56, 54, 53, 52, 49, 45, 48] [1, -2, -1, -1, -3, -4, 3]
# False
# False
# False
#
# 0
# [44, 47, 51, 52, 55, 56, 57, 59] [3, 4, 1, 3, 1, 1, 2]
# False
# True
# False
#
# 0
# [88, 92, 97, 99, 99] [4, 5, 2, 0]
# False
# False
# False
#
# 0
# [9, 9, 10, 13, 15, 15] [0, 1, 3, 2, 0]
# False
# False
# False
#
# 0
# [13, 10, 7, 9, 10, 12, 12] [-3, -3, 2, 1, 2, 0]
# False
# False
# False
#
# 0
# [34, 29, 28, 22, 25] [-5, -1, -6, 3]
# False
# False
# False
#
# 0
# [51, 51, 53, 56, 59, 60] [0, 2, 3, 3, 1]
# False
# False
# False
#
# 0
# [55, 56, 59, 61, 63, 62, 62] [1, 3, 2, 2, -1, 0]
# False
# False
# False
#
# 0
# [66, 71, 73, 75, 78, 81, 81, 86] [5, 2, 2, 3, 3, 0, 5]
# False
# False
# False
#
# 0
# [19, 20, 21, 24, 26, 32, 35] [1, 1, 3, 2, 6, 3]
# False
# True
# False
#
# 0
# [65, 64, 58, 56, 53] [-1, -6, -2, -3]
# False
# True
# False
#
# 0
# [27, 27, 28, 33, 35, 41] [0, 1, 5, 2, 6]
# False
# False
# False
#
# 0
# [80, 79, 78, 80, 77] [-1, -1, 2, -3]
# True
# False
# False
#
# 0
# [61, 57, 53, 51, 48, 46] [-4, -4, -2, -3, -2]
# False
# True
# False
#
# 0
# [97, 93, 90, 83, 80, 79, 78] [-4, -3, -7, -3, -1, -1]
# False
# True
# False
#
# 0
# [37, 42, 45, 47, 50, 52, 53, 58] [5, 3, 2, 3, 2, 1, 5]
# False
# True
# False
#
# 0
# [27, 31, 32, 35, 36, 39, 36, 36] [4, 1, 3, 1, 3, -3, 0]
# False
# False
# False
#
# 0
# [14, 15, 13, 10, 6, 2] [1, -2, -3, -4, -4]
# False
# False
# False
#
# 0
# [81, 86, 89, 90, 90] [5, 3, 1, 0]
# False
# False
# False
#
# 0
# [80, 74, 73, 70, 69, 67, 66, 69] [-6, -1, -3, -1, -2, -1, 3]
# False
# False
# False
#
# 0
# [49, 46, 44, 41, 37, 37] [-3, -2, -3, -4, 0]
# False
# False
# False
#
# 0
# [88, 85, 87, 88, 89, 93] [-3, 2, 1, 1, 4]
# False
# False
# False
#
# 0
# [40, 34, 32, 29, 30, 28, 31] [-6, -2, -3, 1, -2, 3]
# False
# False
# False
#
# 0
# [37, 34, 33, 32, 31, 29, 28] [-3, -1, -1, -1, -2, -1]
# True
# True
# True
#
# 1
# [70, 73, 75, 78, 79, 81, 84, 85] [3, 2, 3, 1, 2, 3, 1]
# True
# True
# True
#
# 1
# [43, 41, 39, 36, 35, 34, 33, 31] [-2, -2, -3, -1, -1, -1, -2]
# True
# True
# True
#
# 1
# [95, 93, 92, 90, 89, 87, 85, 84] [-2, -1, -2, -1, -2, -2, -1]
# True
# True
# True
#
# 1
# [33, 31, 28, 26, 23, 22, 19, 16] [-2, -3, -2, -3, -1, -3, -3]
# True
# True
# True
#
# 1
# [2, 5, 7, 9, 12, 13] [3, 2, 2, 3, 1]
# True
# True
# True
#
# 1
# [55, 54, 52, 50, 49, 47] [-1, -2, -2, -1, -2]
# True
# True
# True
#
# 1
# [41, 42, 45, 48, 50, 53, 54, 55] [1, 3, 3, 2, 3, 1, 1]
# True
# True
# True
#
# 1
# [74, 76, 79, 82, 85, 87, 89, 90] [2, 3, 3, 3, 2, 2, 1]
# True
# True
# True
#
# 1
# [9, 10, 12, 14, 16, 18, 20, 21] [1, 2, 2, 2, 2, 2, 1]
# True
# True
# True
#
# 1
# [95, 92, 90, 87, 85, 82] [-3, -2, -3, -2, -3]
# True
# True
# True
#
# 1
# [82, 83, 86, 89, 92, 95, 98] [1, 3, 3, 3, 3, 3]
# True
# True
# True
#
# 1
# [33, 36, 38, 41, 44, 45, 48, 50] [3, 2, 3, 3, 1, 3, 2]
# True
# True
# True
#
# 1
# [50, 49, 47, 44, 43] [-1, -2, -3, -1]
# True
# True
# True
#
# 1
# [82, 80, 79, 76, 74, 73, 70] [-2, -1, -3, -2, -1, -3]
# True
# True
# True
#
# 1
# [4, 7, 10, 11, 14] [3, 3, 1, 3]
# True
# True
# True
#
# 1
# [90, 88, 86, 84, 82, 79] [-2, -2, -2, -2, -3]
# True
# True
# True
#
# 1
# [41, 42, 44, 45, 47, 50, 53, 56] [1, 2, 1, 2, 3, 3, 3]
# True
# True
# True
#
# 1
# [62, 59, 56, 53, 51, 50, 49, 48] [-3, -3, -3, -2, -1, -1, -1]
# True
# True
# True
#
# 1
# [61, 59, 57, 54, 51, 50, 49] [-2, -2, -3, -3, -1, -1]
# True
# True
# True
#
# 1
# [51, 53, 56, 57, 58, 59, 61] [2, 3, 1, 1, 1, 2]
# True
# True
# True
#
# 1
# [68, 67, 66, 64, 62, 61, 58] [-1, -1, -2, -2, -1, -3]
# True
# True
# True
#
# 1
# [8, 10, 12, 15, 16, 18] [2, 2, 3, 1, 2]
# True
# True
# True
#
# 1
# [7, 9, 12, 15, 16] [2, 3, 3, 1]
# True
# True
# True
#
# 1
# [72, 71, 68, 66, 63] [-1, -3, -2, -3]
# True
# True
# True
#
# 1
# [47, 46, 43, 42, 40, 39, 37, 35] [-1, -3, -1, -2, -1, -2, -2]
# True
# True
# True
#
# 1
# [45, 43, 42, 41, 39, 36] [-2, -1, -1, -2, -3]
# True
# True
# True
#
# 1
# [80, 82, 85, 86, 89, 90, 93, 96] [2, 3, 1, 3, 1, 3, 3]
# True
# True
# True
#
# 1
# [19, 16, 13, 10, 7, 5, 4] [-3, -3, -3, -3, -2, -1]
# True
# True
# True
#
# 1
# [78, 81, 84, 86, 88, 89, 91] [3, 3, 2, 2, 1, 2]
# True
# True
# True
#
# 1
# [45, 42, 40, 37, 35] [-3, -2, -3, -2]
# True
# True
# True
#
# 1
# [34, 37, 40, 43, 44, 46, 48, 50] [3, 3, 3, 1, 2, 2, 2]
# True
# True
# True
#
# 1
# [58, 60, 61, 62, 65, 66] [2, 1, 1, 3, 1]
# True
# True
# True
#
# 1
# [31, 30, 27, 26, 24, 21, 18] [-1, -3, -1, -2, -3, -3]
# True
# True
# True
#
# 1
# [29, 28, 27, 26, 23] [-1, -1, -1, -3]
# True
# True
# True
#
# 1
# [9, 11, 13, 16, 18, 19, 21, 24] [2, 2, 3, 2, 1, 2, 3]
# True
# True
# True
#
# 1
# [54, 52, 51, 48, 45, 44, 43] [-2, -1, -3, -3, -1, -1]
# True
# True
# True
#
# 1
# [5, 7, 10, 12, 14, 17, 19, 20] [2, 3, 2, 2, 3, 2, 1]
# True
# True
# True
#
# 1
# [9, 10, 11, 14, 16, 18] [1, 1, 3, 2, 2]
# True
# True
# True
#
# 1
# [18, 16, 14, 13, 10] [-2, -2, -1, -3]
# True
# True
# True
#
# 1
# [46, 44, 42, 40, 39, 38, 36] [-2, -2, -2, -1, -1, -2]
# True
# True
# True
#
# 1
# [52, 51, 48, 45, 43] [-1, -3, -3, -2]
# True
# ...
#
# 1
# [47, 50, 53, 54, 55, 58, 60] [3, 3, 1, 1, 3, 2]
# True
# True
# True
#
# 1
# [21, 19, 16, 13, 11] [-2, -3, -3, -2]
# True
# True
# True
#
# 1
# [80, 82, 83, 84, 85] [2, 1, 1, 1]
# True
# True
# True
#
# 1
# [92, 91, 90, 87, 85, 84, 83, 80] [-1, -1, -3, -2, -1, -1, -3]
# True
# True
# True
#
# 1
# [43, 46, 47, 50, 53] [3, 1, 3, 3]
# True
# True
# True
#
# 1
# [20, 23, 24, 25, 28] [3, 1, 1, 3]
# True
# True
# True
#
# 1
# [18, 19, 22, 25, 28, 29, 31, 34] [1, 3, 3, 3, 1, 2, 3]
# True
# True
# True
#
# 1
# [44, 47, 48, 49, 50, 51, 52, 54] [3, 1, 1, 1, 1, 1, 2]
# True
# True
# True
#
# 1
# [72, 70, 69, 67, 66, 64] [-2, -1, -2, -1, -2]
# True
# True
# True
#
# 1
# [20, 18, 17, 16, 15, 13, 11, 9] [-2, -1, -1, -1, -2, -2, -2]
# True
# True
# True
#
# 1
# [45, 47, 49, 52, 53, 56, 58] [2, 2, 3, 1, 3, 2]
# True
# True
# True
#
# 1
# [82, 84, 86, 89, 90] [2, 2, 3, 1]
# True
# True
# True
#
# 1
# [79, 81, 83, 84, 87, 90, 91, 92] [2, 2, 1, 3, 3, 1, 1]
# True
# True
# True
#
# 1
# [14, 17, 19, 22, 23, 24, 27] [3, 2, 3, 1, 1, 3]
# True
# True
# True
#
# 1
# [18, 15, 12, 10, 7, 5] [-3, -3, -2, -3, -2]
# True
# True
# True
#
# 1
# [72, 69, 68, 65, 63] [-3, -1, -3, -2]
# True
# True
# True
#
# 1
# [49, 47, 45, 44, 43, 40, 37] [-2, -2, -1, -1, -3, -3]
# True
# True
# True
#
# 1
# [17, 20, 21, 23, 25, 27] [3, 1, 2, 2, 2]
# True
# True
# True
#
# 1
# [65, 63, 62, 59, 58] [-2, -1, -3, -1]
# True
# True
# True
#
# 1
# [64, 61, 58, 56, 54] [-3, -3, -2, -2]
# True
# True
# True
#
# 1
# [76, 73, 71, 70, 67, 64] [-3, -2, -1, -3, -3]
# True
# True
# True
#
# 1
# [61, 64, 65, 66, 69] [3, 1, 1, 3]
# True
# True
# True
#
# 1
# [19, 22, 23, 24, 27, 28, 29] [3, 1, 1, 3, 1, 1]
# True
# True
# True
#
# 1
# [46, 45, 43, 41, 39, 37] [-1, -2, -2, -2, -2]
# True
# True
# True
#
# 1
# [15, 12, 9, 6, 5, 2, 1] [-3, -3, -3, -1, -3, -1]
# True
# True
# True
#
# 1
# [32, 30, 29, 26, 23, 20] [-2, -1, -3, -3, -3]
# True
# True
# True
#
# 1
# [16, 19, 22, 24, 27, 29, 31, 34] [3, 3, 2, 3, 2, 2, 3]
# True
# True
# True
#
# 1
# [61, 58, 55, 52, 51, 50, 47, 45] [-3, -3, -3, -1, -1, -3, -2]
# True
# True
# True
#
# 1
# [57, 55, 52, 49, 47, 46] [-2, -3, -3, -2, -1]
# True
# True
# True
#
# 1
# [98, 95, 92, 90, 89] [-3, -3, -2, -1]
# True
# True
# True
#
# 1
# [21, 18, 17, 15, 14, 12] [-3, -1, -2, -1, -2]
# True
# True
# True
#
# 1
# [62, 65, 68, 71, 73, 76] [3, 3, 3, 2, 3]
# True
# True
# True
#
# 1
# [74, 72, 69, 66, 63, 61] [-2, -3, -3, -3, -2]
# True
# True
# True
#
# 1
# [13, 12, 10, 9, 6, 4, 3, 1] [-1, -2, -1, -3, -2, -1, -2]
# True
# True
# True
#
# 1
# [92, 89, 86, 84, 83, 80, 77] [-3, -3, -2, -1, -3, -3]
# True
# True
# True
#
# 1
# [62, 63, 64, 65, 67, 68, 71] [1, 1, 1, 2, 1, 3]
# True
# True
# True
#
# 1
# [73, 74, 75, 77, 78, 80, 82] [1, 1, 2, 1, 2, 2]
# True
# True
# True
#
# 1
# [54, 57, 58, 59, 60, 62, 64, 65] [3, 1, 1, 1, 2, 2, 1]
# True
# True
# True
#
# 1
# [76, 73, 71, 68, 67, 65, 62, 60] [-3, -2, -3, -1, -2, -3, -2]
# True
# True
# True
#
# 1
# [44, 46, 47, 48, 51] [2, 1, 1, 3]
# True
# True
# True
#
# 1
# [23, 24, 27, 28, 29, 32] [1, 3, 1, 1, 3]
# True
# True
# True
#
# 1
# [68, 71, 72, 75, 78, 81] [3, 1, 3, 3, 3]
# True
# True
# True
#
# 1
# [16, 19, 22, 24, 26] [3, 3, 2, 2]
# True
# True
# True
#
# 1
# [9, 11, 13, 16, 18, 20, 23] [2, 2, 3, 2, 2, 3]
# True
# True
# True
#
# 1
# [73, 70, 68, 67, 66, 64, 62] [-3, -2, -1, -1, -2, -2]
# True
# True
# True
#
# 1
# [79, 81, 82, 84, 85] [2, 1, 2, 1]
# True
# True
# True
#
# 1
# [64, 61, 60, 59, 57, 54, 51, 48] [-3, -1, -1, -2, -3, -3, -3]
# True
# True
# True
#
# 1
# [11, 8, 5, 4, 1] [-3, -3, -1, -3]
# True
# True
# True
#
# 1
# [76, 73, 70, 67, 65, 62, 61, 60] [-3, -3, -3, -2, -3, -1, -1]
# True
# True
# True
#
# 1
# [69, 70, 73, 76, 77, 80, 82, 85] [1, 3, 3, 1, 3, 2, 3]
# True
# True
# True
#
# 1
# [67, 64, 63, 61, 59, 58, 57, 56] [-3, -1, -2, -2, -1, -1, -1]
# True
# True
# True
#
# 1
# [66, 65, 64, 61, 58, 55, 53, 51] [-1, -1, -3, -3, -3, -2, -2]
# True
# True
# True
#
# 1
# [41, 44, 47, 50, 51, 54, 55] [3, 3, 3, 1, 3, 1]
# True
# True
# True
#
# 1
# [63, 60, 59, 56, 55, 54, 53, 51] [-3, -1, -3, -1, -1, -1, -2]
# True
# True
# True
#
# 1
# [36, 33, 31, 29, 26, 25] [-3, -2, -2, -3, -1]
# True
# True
# True
#
# 1
# [9, 7, 6, 5, 4] [-2, -1, -1, -1]
# True
# True
# True
#
# 1
# [73, 71, 68, 65, 62] [-2, -3, -3, -3]
# True
# True
# True
#
# 1
# [80, 77, 76, 74, 71, 68, 67] [-3, -1, -2, -3, -3, -1]
# True
# True
# True
#
# 1
# [29, 30, 32, 35, 37, 39] [1, 2, 3, 2, 2]
# True
# True
# True
#
# 1
# [18, 17, 15, 12, 9, 7, 5, 4] [-1, -2, -3, -3, -2, -2, -1]
# True
# True
# True
#
# 1
# [75, 73, 71, 70, 69, 67, 64, 61] [-2, -2, -1, -1, -2, -3, -3]
# True
# True
# True
#
# 1
# [59, 57, 54, 53, 50, 47] [-2, -3, -1, -3, -3]
# True
# True
# True
#
# 1
# [85, 88, 89, 90, 92, 93] [3, 1, 1, 2, 1]
# True
# True
# True
#
# 1
# [7, 8, 10, 13, 15, 17, 19, 21] [1, 2, 3, 2, 2, 2, 2]
# True
# True
# True
#
# 1
# [79, 76, 74, 73, 71, 68, 67] [-3, -2, -1, -2, -3, -1]
# True
# True
# True
#
# 1
# [52, 49, 48, 46, 43, 40, 38, 37] [-3, -1, -2, -3, -3, -2, -1]
# True
# True
# True
#
# 1
# [96, 95, 93, 90, 87, 86, 83] [-1, -2, -3, -3, -1, -3]
# True
# True
# True
#
# 1
# [20, 17, 16, 15, 12, 11, 10, 8] [-3, -1, -1, -3, -1, -1, -2]
# True
# True
# True
#
# 1
# [61, 60, 58, 57, 54, 53, 52, 51] [-1, -2, -1, -3, -1, -1, -1]
# True
# True
# True
#
# 1
# [62, 61, 60, 59, 56, 54] [-1, -1, -1, -3, -2]
# True
# True
# True
#
# 1
# [17, 16, 15, 12, 11, 8, 7] [-1, -1, -3, -1, -3, -1]
# True
# True
# True
#
# 1
# [35, 33, 32, 29, 26, 24, 22, 19] [-2, -1, -3, -3, -2, -2, -3]
# True
# True
# True
#
# 1
# [16, 18, 21, 22, 25, 28] [2, 3, 1, 3, 3]
# True
# True
# True
#
# 1
# [59, 58, 57, 55, 54, 53, 50] [-1, -1, -2, -1, -1, -3]
# True
# True
# True
#
# 1
# [51, 53, 55, 56, 58, 60, 62] [2, 2, 1, 2, 2, 2]
# True
# True
# True
#
# 1
# [38, 39, 42, 43, 46, 48, 49] [1, 3, 1, 3, 2, 1]
# True
# True
# True
#
# 1
# [12, 15, 16, 17, 19, 22] [3, 1, 1, 2, 3]
# True
# True
# True
#
# 1
# [42, 44, 45, 46, 48, 50] [2, 1, 1, 2, 2]
# True
# True
# True
#
# 1
# [41, 40, 39, 36, 33, 31] [-1, -1, -3, -3, -2]
# True
# True
# True
#
# 1
# [47, 49, 50, 51, 53, 55] [2, 1, 1, 2, 2]
# True
# True
# True
#
# 1
# [92, 89, 87, 85, 82, 79, 76, 74] [-3, -2, -2, -3, -3, -3, -2]
# True
# True
# True
#
# 1
# [75, 76, 78, 79, 82] [1, 2, 1, 3]
# True
# True
# True
#
# 1
# [30, 27, 24, 22, 19] [-3, -3, -2, -3]
# True
# True
# True
#
# 1
# [80, 81, 82, 83, 84, 85, 86, 89] [1, 1, 1, 1, 1, 1, 3]
# True
# True
# True
#
# 1
# [55, 56, 57, 59, 62, 63, 66, 69] [1, 1, 2, 3, 1, 3, 3]
# True
# True
# True
#
# 1
# [73, 74, 77, 80, 83, 85, 87, 89] [1, 3, 3, 3, 2, 2, 2]
# True
# True
# True
#
# 1
# [89, 87, 86, 85, 83, 80, 77, 75] [-2, -1, -1, -2, -3, -3, -2]
# True
# True
# True
#
# 1
# [39, 41, 42, 43, 45, 46, 49, 50] [2, 1, 1, 2, 1, 3, 1]
# True
# True
# True
#
# 1
# [52, 54, 57, 58, 59, 62, 65, 67] [2, 3, 1, 1, 3, 3, 2]
# True
# True
# True
#
# 1
# [50, 52, 54, 57, 58, 61, 63, 64] [2, 2, 3, 1, 3, 2, 1]
# True
# True
# True
#
# 1
# [9, 11, 14, 17, 18] [2, 3, 3, 1]
# True
# True
# True
#
# 1
# [60, 59, 58, 55, 53, 52, 50, 48] [-1, -1, -3, -2, -1, -2, -2]
# True
# True
# True
#
# 1
# [52, 54, 55, 57, 58] [2, 1, 2, 1]
# True
# True
# True
#
# 1
# [87, 90, 92, 93, 95, 98, 99] [3, 2, 1, 2, 3, 1]
# True
# True
# True
#
# 1
# [90, 88, 86, 83, 81, 80, 78] [-2, -2, -3, -2, -1, -2]
# True
# True
# True
#
# 1
# [91, 88, 85, 84, 81, 79, 78, 76] [-3, -3, -1, -3, -2, -1, -2]
# True
# True
# True
#
# 1
# [35, 33, 32, 30, 28, 26, 24] [-2, -1, -2, -2, -2, -2]
# True
# True
# True
#
# 1
# [41, 40, 39, 36, 35, 33, 30, 29] [-1, -1, -3, -1, -2, -3, -1]
# True
# True
# True
#
# 1
# [89, 91, 94, 96, 99] [2, 3, 2, 3]
# True
# True
# True
#
# 1
# [74, 76, 79, 80, 83, 84, 87] [2, 3, 1, 3, 1, 3]
# True
# True
# True
#
# 1
# [62, 59, 56, 54, 51, 49] [-3, -3, -2, -3, -2]
# True
# True
# True
#
# 1
# [17, 15, 13, 12, 10, 8, 5] [-2, -2, -1, -2, -2, -3]
# True
# True
# True
#
# 1
# [83, 84, 85, 86, 87, 88] [1, 1, 1, 1, 1]
# True
# True
# True
#
# 1
# [16, 13, 10, 7, 6, 3, 2] [-3, -3, -3, -1, -3, -1]
# True
# True
# True
#
# 1
# [63, 64, 66, 68, 69, 71, 73, 76] [1, 2, 2, 1, 2, 2, 3]
# True
# True
# True
#
# 1
# [82, 84, 87, 90, 92, 95, 98] [2, 3, 3, 2, 3, 3]
# True
# True
# True
#
# 1
# [12, 13, 15, 16, 17, 19] [1, 2, 1, 1, 2]
# True
# True
# True
#
# 1
# [79, 80, 81, 83, 84, 85, 87, 88] [1, 1, 2, 1, 1, 2, 1]
# True
# True
# True
#
# 1
# [20, 23, 25, 28, 31, 33, 34, 36] [3, 2, 3, 3, 2, 1, 2]
# True
# True
# True
#
# 1
# [5, 7, 10, 12, 14] [2, 3, 2, 2]
# True
# True
# True
#
# 1
# [84, 85, 87, 88, 90, 92, 95] [1, 2, 1, 2, 2, 3]
# True
# True
# True
#
# 1
# [48, 51, 53, 54, 57] [3, 2, 1, 3]
# True
# True
# True
#
# 1
# [53, 56, 58, 60, 61, 64, 66] [3, 2, 2, 1, 3, 2]
# True
# True
# True
#
# 1
# [77, 76, 73, 72, 69, 67] [-1, -3, -1, -3, -2]
# True
# True
# True
#
# 1
# [65, 62, 61, 59, 58, 55] [-3, -1, -2, -1, -3]
# True
# True
# True
#
# 1
# [75, 74, 72, 70, 67, 64] [-1, -2, -2, -3, -3]
# True
# True
# True
#
# 1
# [59, 58, 57, 56, 55, 54] [-1, -1, -1, -1, -1]
# True
# True
# True
#
# 1
# [67, 65, 64, 62, 60, 59, 58] [-2, -1, -2, -2, -1, -1]
# True
# True
# True
#
# 1
# [72, 73, 74, 75, 78, 79, 81] [1, 1, 1, 3, 1, 2]
# True
# True
# True
#
# 1
# [62, 64, 67, 68, 71, 72, 75] [2, 3, 1, 3, 1, 3]
# True
# True
# True
#
# 1
# [6, 9, 12, 15, 16, 17] [3, 3, 3, 1, 1]
# True
# True
# True
#
# 1
# [34, 36, 39, 41, 43, 44] [2, 3, 2, 2, 1]
# True
# True
# True
#
# 1
# [41, 42, 45, 46, 48, 51] [1, 3, 1, 2, 3]
# True
# True
# True
#
# 1
# [49, 50, 52, 55, 57, 60, 62, 63] [1, 2, 3, 2, 3, 2, 1]
# True
# True
# True
#
# 1
# [55, 56, 59, 60, 62, 64, 65] [1, 3, 1, 2, 2, 1]
# True
# True
# True
#
# 1
# [86, 89, 90, 93, 96] [3, 1, 3, 3]
# True
# True
# True
#
# 1
# [80, 78, 75, 74, 71, 70, 68, 65] [-2, -3, -1, -3, -1, -2, -3]
# True
# True
# True
#
# 1
# [83, 81, 79, 76, 74, 73] [-2, -2, -3, -2, -1]
# True
# True
# True
#
# 1
# [69, 68, 65, 62, 61, 59] [-1, -3, -3, -1, -2]
# True
# True
# True
#
# 1
# [80, 83, 84, 87, 89, 90, 92] [3, 1, 3, 2, 1, 2]
# True
# True
# True
#
# 1
# [33, 31, 29, 27, 24, 22] [-2, -2, -2, -3, -2]
# True
# True
# True
#
# 1
# [31, 34, 36, 39, 41] [3, 2, 3, 2]
# True
# True
# True
#
# 1
# [92, 91, 89, 88, 86, 85, 83] [-1, -2, -1, -2, -1, -2]
# True
# True
# True
#
# 1
# [93, 90, 89, 87, 85, 83] [-3, -1, -2, -2, -2]
# True
# True
# True
#
# 1
# [36, 38, 41, 44, 46, 47] [2, 3, 3, 2, 1]
# True
# True
# True
#
# 1
# [11, 13, 14, 15, 17, 19, 22, 24] [2, 1, 1, 2, 2, 3, 2]
# True
# True
# True
#
# 1
# [4, 6, 7, 9, 10, 13, 15] [2, 1, 2, 1, 3, 2]
# True
# True
# True
#
# 1
# [70, 71, 74, 77, 79, 81] [1, 3, 3, 2, 2]
# True
# True
# True
#
# 1
# [13, 10, 7, 5, 4] [-3, -3, -2, -1]
# True
# True
# True
#
# 1
# [43, 44, 47, 48, 50, 53, 55, 58] [1, 3, 1, 2, 3, 2, 3]
# True
# True
# True
#
# 1
# [60, 61, 63, 65, 67, 68, 70, 72] [1, 2, 2, 2, 1, 2, 2]
# True
# True
# True
#
# 1
# [75, 77, 79, 82, 85, 88] [2, 2, 3, 3, 3]
# True
# True
# True
#
# 1
# [51, 53, 55, 57, 60, 63, 65] [2, 2, 2, 3, 3, 2]
# True
# True
# True
#
# 1
# [17, 20, 21, 24, 26] [3, 1, 3, 2]
# True
# True
# True
#
# 1
# [47, 46, 45, 43, 41, 39, 38] [-1, -1, -2, -2, -2, -1]
# True
# True
# True
#
# 1
# [39, 42, 44, 45, 48, 49, 51] [3, 2, 1, 3, 1, 2]
# True
# True
# True
#
# 1
# [60, 58, 57, 54, 52, 51, 50] [-2, -1, -3, -2, -1, -1]
# True
# True
# True
#
# 1
# [37, 36, 34, 32, 29, 26, 23] [-1, -2, -2, -3, -3, -3]
# True
# True
# True
#
# 1
# [64, 62, 59, 58, 55, 53, 51] [-2, -3, -1, -3, -2, -2]
# True
# True
# True
#
# 1
# [53, 54, 56, 59, 62, 65, 67] [1, 2, 3, 3, 3, 2]
# True
# True
# True
#
# 1
# [72, 71, 69, 68, 67] [-1, -2, -1, -1]
# True
# True
# True
#
# 1
# [48, 45, 42, 41, 40, 38] [-3, -3, -1, -1, -2]
# True
# True
# True
#
# 1
# [52, 50, 49, 46, 44, 43, 42] [-2, -1, -3, -2, -1, -1]
# True
# True
# True
#
# 1
# [16, 13, 12, 11, 10, 9] [-3, -1, -1, -1, -1]
# True
# True
# True
#
# 1
# [28, 27, 24, 22, 21, 19, 18] [-1, -3, -2, -1, -2, -1]
# True
# True
# True
#
# 1
# [9, 12, 14, 17, 20, 22, 25, 26] [3, 2, 3, 3, 2, 3, 1]
# True
# True
# True
#
# 1
# [70, 72, 74, 75, 77, 78] [2, 2, 1, 2, 1]
# True
# True
# True
#
# 1
# [87, 85, 83, 80, 78, 76, 74, 72] [-2, -2, -3, -2, -2, -2, -2]
# True
# True
# True
#
# 1
# [50, 49, 47, 45, 42, 40] [-1, -2, -2, -3, -2]
# True
# True
# True
#
# 1
# [73, 71, 69, 67, 64, 61, 60, 57] [-2, -2, -2, -3, -3, -1, -3]
# True
# True
# True
#
# 1
# [12, 14, 17, 18, 20, 22] [2, 3, 1, 2, 2]
# True
# True
# True
#
# 1
# [77, 74, 73, 72, 69, 67] [-3, -1, -1, -3, -2]
# True
# True
# True
#
# 1
# [77, 74, 72, 69, 67, 66, 63, 60] [-3, -2, -3, -2, -1, -3, -3]
# True
# True
# True
#
# 1
# [53, 56, 59, 60, 63, 65, 66] [3, 3, 1, 3, 2, 1]
# True
# True
# True
#
# 1
# [40, 42, 44, 46, 49, 50, 51, 53] [2, 2, 2, 3, 1, 1, 2]
# True
# True
# True
#
# 1
# [66, 68, 70, 73, 75, 77, 78, 79] [2, 2, 3, 2, 2, 1, 1]
# True
# True
# True
#
# 1
# [34, 35, 38, 41, 43, 45, 48, 50] [1, 3, 3, 2, 2, 3, 2]
# True
# True
# True
#
# 1
# [3, 5, 7, 9, 11, 14] [2, 2, 2, 2, 3]
# True
# True
# True
#
# 1
# [75, 77, 80, 83, 84, 85, 88, 89] [2, 3, 3, 1, 1, 3, 1]
# True
# True
# True
#
# 1
# [90, 91, 93, 94, 96] [1, 2, 1, 2]
# True
# True
# True
#
# 1
# [52, 53, 55, 57, 60] [1, 2, 2, 3]
# True
# True
# True
#
# 1
# [65, 63, 60, 59, 58] [-2, -3, -1, -1]
# True
# True
# True
#
# 1
# [57, 58, 60, 61, 63, 64] [1, 2, 1, 2, 1]
# True
# True
# True
#
# 1
# [20, 19, 18, 16, 15, 13] [-1, -1, -2, -1, -2]
# True
# True
# True
#
# 1
# [18, 19, 20, 21, 24, 27] [1, 1, 1, 3, 3]
# True
# True
# True
#
# 1
# [56, 53, 50, 48, 47] [-3, -3, -2, -1]
# True
# True
# True
#
# 1
# [19, 21, 23, 25, 27, 28, 29, 32] [2, 2, 2, 2, 1, 1, 3]
# True
# True
# True
#
# 1
# [64, 65, 66, 68, 71] [1, 1, 2, 3]
# True
# True
# True
#
# 1
# [88, 87, 85, 82, 81, 78] [-1, -2, -3, -1, -3]
# True
# True
# True
#
# 1
# [58, 59, 62, 64, 67] [1, 3, 2, 3]
# True
# True
# True
#
# 1
# [91, 89, 87, 86, 83, 82] [-2, -2, -1, -3, -1]
# True
# True
# True
#
# 1
# [84, 87, 89, 90, 91, 94, 97] [3, 2, 1, 1, 3, 3]
# True
# True
# True
#
# 1
# [59, 60, 61, 64, 65, 66, 68, 70] [1, 1, 3, 1, 1, 2, 2]
# True
# True
# True
#
# 1
# [70, 73, 74, 76, 78, 81] [3, 1, 2, 2, 3]
# True
# True
# True
#
# 1
# [46, 49, 50, 52, 55] [3, 1, 2, 3]
# True
# True
# True
#
# 1
# [19, 16, 14, 13, 10, 9, 8] [-3, -2, -1, -3, -1, -1]
# True
# True
# True
#
# 1
# [79, 76, 73, 70, 69, 66, 65] [-3, -3, -3, -1, -3, -1]
# True
# True
# True
#
# 1
# [34, 33, 32, 30, 28, 26] [-1, -1, -2, -2, -2]
# True
# True
# True
#
# 1
# [15, 18, 20, 21, 23, 26] [3, 2, 1, 2, 3]
# True
# True
# True
#
# 1
# [89, 92, 93, 96, 99] [3, 1, 3, 3]
# True
# True
# True
#
# 1
# [95, 92, 91, 90, 87] [-3, -1, -1, -3]
# True
# True
# True
#
# 1
# [17, 16, 15, 12, 10, 8] [-1, -1, -3, -2, -2]
# True
# True
# True
#
# 1
# [47, 48, 50, 53, 55, 58] [1, 2, 3, 2, 3]
# True
# True
# True
#
# 1
# [19, 21, 24, 26, 29, 30, 32, 33] [2, 3, 2, 3, 1, 2, 1]
# True
# True
# True
#
# 1
# [35, 37, 40, 43, 44, 47, 50, 51] [2, 3, 3, 1, 3, 3, 1]
# True
# True
# True
#
# 1
# [1, 2, 5, 6, 8, 11] [1, 3, 1, 2, 3]
# True
# True
# True
#
# 1
# [59, 57, 56, 54, 53, 52, 50, 49] [-2, -1, -2, -1, -1, -2, -1]
# True
# True
# True
#
# 1
# [21, 24, 25, 27, 30, 31] [3, 1, 2, 3, 1]
# True
# True
# True
#
# 1
# [32, 31, 30, 29, 27, 26] [-1, -1, -1, -2, -1]
# True
# True
# True
#
# 1
# [32, 29, 26, 24, 23, 21] [-3, -3, -2, -1, -2]
# True
# True
# True
#
# 1
# [20, 17, 15, 12, 11, 8, 7, 4] [-3, -2, -3, -1, -3, -1, -3]
# True
# True
# True
#
# 1
# [60, 57, 56, 54, 53, 52, 51, 48] [-3, -1, -2, -1, -1, -1, -3]
# True
# True
# True
#
# 1
# [72, 71, 70, 68, 67, 64, 62, 60] [-1, -1, -2, -1, -3, -2, -2]
# True
# True
# True
#
# 1
# [53, 51, 50, 47, 44, 41, 40, 38] [-2, -1, -3, -3, -3, -1, -2]
# True
# True
# True
#
# 1
# [86, 89, 91, 93, 95] [3, 2, 2, 2]
# True
# True
# True
#
# 1
# [8, 10, 12, 13, 14, 15, 18, 21] [2, 2, 1, 1, 1, 3, 3]
# True
# True
# True
#
# 1
# [69, 70, 71, 72, 73, 74, 76] [1, 1, 1, 1, 1, 2]
# True
# True
# True
#
# 1
# [34, 32, 29, 26, 25, 23, 21] [-2, -3, -3, -1, -2, -2]
# True
# True
# True
#
# 1
# [70, 67, 64, 63, 62, 59, 57] [-3, -3, -1, -1, -3, -2]
# True
# True
# True
#
# 1
# [60, 59, 57, 56, 53, 52, 49] [-1, -2, -1, -3, -1, -3]
# True
# True
# True
#
# 1
# [83, 85, 86, 88, 89] [2, 1, 2, 1]
# True
# True
# True
#
# 1
# [91, 88, 85, 84, 81] [-3, -3, -1, -3]
# True
# True
# True
#
# 1
# [86, 84, 83, 81, 78] [-2, -1, -2, -3]
# True
# True
# True
#
# 1
# [49, 52, 53, 54, 57] [3, 1, 1, 3]
# True
# True
# True
#
# 1
# [8, 9, 11, 14, 16, 17, 18, 19] [1, 2, 3, 2, 1, 1, 1]
# True
# True
# True
#
# 1
# [77, 80, 82, 85, 86, 88, 90, 92] [3, 2, 3, 1, 2, 2, 2]
# True
# True
# True
#
# 1
# [57, 59, 60, 63, 65, 67, 68] [2, 1, 3, 2, 2, 1]
# True
# True
# True
#
# 1
# [71, 69, 66, 64, 61, 59, 57] [-2, -3, -2, -3, -2, -2]
# True
# True
# True
#
# 1
# [76, 74, 71, 69, 66, 65] [-2, -3, -2, -3, -1]
# True
# True
# True
#
# 1
# [33, 35, 36, 38, 39, 41, 44, 47] [2, 1, 2, 1, 2, 3, 3]
# True
# True
# True
#
# 1
# [81, 84, 86, 89, 90, 93] [3, 2, 3, 1, 3]
# True
# True
# True
#
# 1
# [79, 78, 77, 76, 75, 72, 70, 69] [-1, -1, -1, -1, -3, -2, -1]
# True
# True
# True
#
# 1
# [20, 23, 24, 27, 28, 31] [3, 1, 3, 1, 3]
# True
# True
# True
#
# 1
# [61, 59, 58, 57, 56, 54, 51, 49] [-2, -1, -1, -1, -2, -3, -2]
# True
# True
# True
#
# 1
# [28, 30, 31, 32, 35, 36, 37] [2, 1, 1, 3, 1, 1]
# True
# True
# True
#
# 1
# [55, 56, 58, 61, 63, 65] [1, 2, 3, 2, 2]
# True
# True
# True
#
# 1
# [63, 62, 59, 56, 54] [-1, -3, -3, -2]
# True
# True
# True
#
# 1
# [33, 32, 30, 28, 27] [-1, -2, -2, -1]
# True
# True
# True
#
# 1
# [23, 20, 19, 18, 15, 13, 12, 9] [-3, -1, -1, -3, -2, -1, -3]
# True
# True
# True
#
# 1
# [68, 66, 63, 61, 59, 58, 56, 53] [-2, -3, -2, -2, -1, -2, -3]
# True
# True
# True
#
# 1
# [87, 90, 92, 94, 95, 97] [3, 2, 2, 1, 2]
# True
# True
# True
#
# 1
# [71, 74, 75, 78, 80, 81] [3, 1, 3, 2, 1]
# True
# True
# True
#
# 1
# [81, 79, 76, 73, 71, 69, 68] [-2, -3, -3, -2, -2, -1]
# True
# True
# True
#
# 1
# [57, 59, 62, 64, 66, 68] [2, 3, 2, 2, 2]
# True
# True
# True
#
# 1
# [91, 88, 85, 82, 79, 78, 76] [-3, -3, -3, -3, -1, -2]
# True
# True
# True
#
# 1
# [23, 20, 17, 15, 13, 10] [-3, -3, -2, -2, -3]
# True
# True
# True
#
# 1
# [62, 63, 66, 68, 69, 71] [1, 3, 2, 1, 2]
# True
# True
# True
#
# 1
# [62, 64, 66, 69, 71, 73, 76, 79] [2, 2, 3, 2, 2, 3, 3]
# True
# True
# True
#
# 1
# [30, 31, 33, 36, 39, 40, 41] [1, 2, 3, 3, 1, 1]
# True
# True
# True
#
# 1
# [55, 54, 52, 51, 48, 45, 43] [-1, -2, -1, -3, -3, -2]
# True
# True
# True
#
# 1
# [40, 43, 45, 46, 47, 50] [3, 2, 1, 1, 3]
# True
# True
# True
#
# 1
# [48, 46, 43, 42, 40, 38] [-2, -3, -1, -2, -2]
# True
# True
# True
#
# 1
# [87, 84, 83, 80, 77, 76] [-3, -1, -3, -3, -1]
# True
# True
# True
#
# 1
# 334
